# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
positive_counts?

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects

for i in range(0, len(reviews)):

    words = reviews[i].split(' ')

    is_positive = labels[i] == "POSITIVE"
    
    for j in range(0, len(words)):
        
        word = words[j]
    
        if is_positive:
            positive_counts[word] += 1
        else:
            negative_counts[word] += 1

        total_counts[word] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 1100936),
#  ('the', 519972),
#  ('.', 478962),
#  ('and', 269166),
#  ('a', 251064),
#  ('of', 230565),
#  ('to', 200238),
#  ('is', 171735),
#  ('in', 150645),
#  ('br', 147705),
#  ('it', 144075),
#  ('i', 122229),
#  ('that', 106890),
#  ('this', 105240),
#  ('s', 101445),
#  ('as', 78924),
#  ('with', 69741),
#  ('for', 67248),
#  ('was', 65751),
#  ('film', 62811),
#  ('but', 62466),
#  ('movie', 57222),
#  ('his', 51681),
#  ('on', 51024),
#  ('you', 50043),
#  ('he', 48846),
#  ('are', 44421),
#  ('not', 42816),
#  ('t', 41160),
#  ('one', 40965),
#  ('have', 37761),
#  ('be', 37248),
#  ('by', 35991),
#  ('all', 35826),
#  ('who', 34392),
#  ('an', 33882),
#  ('at', 33702),
#  ('from', 32301),
#  ('her', 31422),
#  ('they', 29685),
#  ('has', 27558),
#  ('so', 27462),
#  ('like', 27114),
#  ('about', 24939),
#  ('very', 24915),
#  ('out', 24402),
#  ('there', 24171),
#  ('she', 23337),
#  ('what', 23211),
#  ('or', 23196),
#  ('good', 23160),
#  ('more', 22563),
#  ('when', 22368),
#  ('some', 22323),
#  ('if', 21855),
#  ('just', 21456),
#  ('can', 21003),
#  ('story', 20340),
#  ('time', 19545),
#  ('my', 19464),
#  ('great', 19257),
#  ('well', 19215),
#  ('up', 18963),
#  ('which', 18801),
#  ('their', 18321),
#  ('see', 18078),
#  ('also', 16650),
#  ('we', 16593),
#  ('really', 16428),
#  ('would', 16200),
#  ('will', 15654),
#  ('me', 15501),
#  ('had', 15444),
#  ('only', 15411),
#  ('him', 15054),
#  ('even', 14892),
#  ('most', 14592),
#  ('other', 14574),
#  ('were', 14346),
#  ('first', 14265),
#  ('than', 14208),
#  ('much', 14055),
#  ('its', 13866),
#  ('no', 13722),
#  ('into', 13632),
#  ('people', 13437),
#  ('best', 12957),
#  ('love', 12903),
#  ('get', 12816),
#  ('how', 12639),
#  ('life', 12597),
#  ('been', 12567),
#  ('because', 12237),
#  ('way', 12108),
#  ('do', 11823),
#  ('made', 11469),
#  ('films', 11439),
#  ('them', 11415),
#  ('after', 11400),
#  ('many', 11298),
#  ('two', 11199),
#  ('too', 10977),
#  ('think', 10965),
#  ('movies', 10758),
#  ('characters', 10680),
#  ('character', 10542),
#  ('don', 10404),
#  ('man', 10380),
#  ('show', 10296),
#  ('watch', 10272),
#  ('seen', 10242),
#  ('then', 10074),
#  ('little', 10023),
#  ('still', 10020),
#  ('make', 9909),
#  ('could', 9711),
#  ('never', 9678),
#  ('being', 9651),
#  ('where', 9519),
#  ('does', 9207),
#  ('over', 9051),
#  ('any', 9006),
#  ('while', 8697),
#  ('know', 8499),
#  ('did', 8370),
#  ('years', 8274),
#  ('here', 8220),
#  ('ever', 8202),
#  ('end', 8088),
#  ('these', 8082),
#  ('such', 7770),
#  ('real', 7704),
#  ('scene', 7701),
#  ('back', 7641),
#  ('those', 7455),
#  ('though', 7425),
#  ('off', 7389),
#  ('new', 7374),
#  ('your', 7359),
#  ('go', 7320),
#  ('acting', 7311),
#  ('plot', 7296),
#  ('world', 7287),
#  ('scenes', 7281),
#  ('say', 7242),
#  ('through', 7227),
#  ('makes', 7170),
#  ('better', 7143),
#  ('now', 7104),
#  ('work', 7038),
#  ('young', 7029),
#  ('old', 6933),
#  ('ve', 6921),
#  ('find', 6816),
#  ('both', 6744),
#  ('before', 6531),
#  ('us', 6486),
#  ('again', 6474),
#  ('series', 6459),
#  ('quite', 6429),
#  ('something', 6405),
#  ('cast', 6399),
#  ('should', 6363),
#  ('part', 6294),
#  ('always', 6264),
#  ('lot', 6261),
#  ('another', 6225),
#  ('actors', 6141),
#  ('director', 6120),
#  ('family', 6096),
#  ('between', 6048),
#  ('own', 6048),
#  ('m', 5994),
#  ('may', 5991),
#  ('same', 5916),
#  ('role', 5901),
#  ('watching', 5898),
#  ('every', 5862),
#  ('funny', 5859),
#  ('doesn', 5805),
#  ('performance', 5784),
#  ('few', 5754),
#  ('bad', 5721),
#  ('look', 5700),
#  ('re', 5652),
#  ('why', 5565),
#  ('things', 5547),
#  ('times', 5496),
#  ('big', 5445),
#  ('however', 5385),
#  ('actually', 5370),
#  ('action', 5367),
#  ('going', 5349),
#  ('bit', 5271),
#  ('comedy', 5226),
#  ('down', 5220),
#  ('music', 5214),
#  ('must', 5184),
#  ('take', 5127),
#  ('saw', 5076),
#  ('long', 5070),
#  ('right', 5064),
#  ('fun', 5058),
#  ('fact', 5052),
#  ('excellent', 5049),
#  ('around', 5022),
#  ('didn', 5016),
#  ('without', 5013),
#  ('thing', 4986),
#  ('thought', 4917),
#  ('got', 4905),
#  ('each', 4890),
#  ('day', 4842),
#  ('feel', 4791),
#  ('seems', 4788),
#  ('come', 4782),
#  ('done', 4758),
#  ('beautiful', 4740),
#  ('especially', 4716),
#  ('played', 4713),
#  ('almost', 4698),
#  ('want', 4686),
#  ('yet', 4668),
#  ('give', 4659),
#  ('pretty', 4647),
#  ('last', 4629),
#  ('since', 4557),
#  ('different', 4512),
#  ('although', 4503),
#  ('gets', 4470),
#  ('true', 4461),
#  ('interesting', 4443),
#  ('job', 4410),
#  ('enough', 4365),
#  ('our', 4362),
#  ('shows', 4341),
#  ('horror', 4323),
#  ('woman', 4317),
#  ('tv', 4200),
#  ('probably', 4194),
#  ('father', 4185),
#  ('original', 4179),
#  ('girl', 4170),
#  ('point', 4137),
#  ('plays', 4134),
#  ('wonderful', 4116),
#  ('far', 4074),
#  ('course', 4074),
#  ('john', 4050),
#  ('rather', 4020),
#  ('isn', 3984),
#  ('ll', 3978),
#  ('later', 3972),
#  ('dvd', 3972),
#  ('whole', 3930),
#  ('war', 3930),
#  ('d', 3921),
#  ('found', 3918),
#  ('away', 3918),
#  ('screen', 3915),
#  ('nothing', 3900),
#  ('year', 3891),
#  ('once', 3888),
#  ('hard', 3882),
#  ('together', 3840),
#  ('set', 3831),
#  ('am', 3831),
#  ('having', 3798),
#  ('making', 3795),
#  ('place', 3789),
#  ('might', 3780),
#  ('comes', 3780),
#  ('sure', 3759),
#  ('american', 3744),
#  ('play', 3735),
#  ('kind', 3732),
#  ('perfect', 3726),
#  ('takes', 3726),
#  ('performances', 3711),
#  ('himself', 3690),
#  ('worth', 3663),
#  ('everyone', 3663),
#  ('anyone', 3642),
#  ('actor', 3609),
#  ('three', 3603),
#  ('wife', 3588),
#  ('classic', 3576),
#  ('goes', 3558),
#  ('ending', 3534),
#  ('version', 3504),
#  ('star', 3447),
#  ('enjoy', 3438),
#  ('book', 3426),
#  ('nice', 3396),
#  ('everything', 3384),
#  ('during', 3372),
#  ('put', 3354),
#  ('seeing', 3333),
#  ('least', 3306),
#  ('house', 3300),
#  ('high', 3285),
#  ('watched', 3282),
#  ('loved', 3261),
#  ('men', 3261),
#  ('night', 3246),
#  ('anything', 3225),
#  ('believe', 3213),
#  ('guy', 3213),
#  ('top', 3189),
#  ('amazing', 3174),
#  ('hollywood', 3168),
#  ('looking', 3159),
#  ('main', 3132),
#  ('definitely', 3129),
#  ('gives', 3093),
#  ('home', 3087),
#  ('seem', 3084),
#  ('episode', 3069),
#  ('audience', 3060),
#  ('sense', 3060),
#  ('truly', 3051),
#  ('special', 3033),
#  ('second', 3027),
#  ('short', 3027),
#  ('fan', 3027),
#  ('mind', 3015),
#  ('human', 3003),
#  ('recommend', 2997),
#  ('full', 2988),
#  ('black', 2985),
#  ('help', 2973),
#  ('along', 2967),
#  ('trying', 2961),
#  ('small', 2958),
#  ('death', 2955),
#  ('friends', 2943),
#  ('remember', 2922),
#  ('often', 2910),
#  ('said', 2898),
#  ('favorite', 2886),
#  ('heart', 2877),
#  ('early', 2871),
#  ('left', 2868),
#  ('until', 2865),
#  ('script', 2862),
#  ('let', 2862),
#  ('maybe', 2811),
#  ('today', 2808),
#  ('live', 2802),
#  ('less', 2802),
#  ('moments', 2799),
#  ('others', 2787),
#  ('brilliant', 2778),
#  ('shot', 2775),
#  ('liked', 2769),
#  ('become', 2748),
#  ('won', 2745),
#  ('used', 2730),
#  ('style', 2721),
#  ('mother', 2685),
#  ('lives', 2682),
#  ('came', 2679),
#  ('stars', 2670),
#  ('cinema', 2667),
#  ('looks', 2655),
#  ('perhaps', 2652),
#  ('read', 2646),
#  ('enjoyed', 2637),
#  ('boy', 2625),
#  ('drama', 2619),
#  ('highly', 2613),
#  ('given', 2610),
#  ('playing', 2601),
#  ('use', 2592),
#  ('next', 2577),
#  ('women', 2574),
#  ('fine', 2571),
#  ('effects', 2568),
#  ('kids', 2562),
#  ('entertaining', 2559),
#  ('need', 2556),
#  ('line', 2550),
#  ('works', 2544),
#  ('someone', 2541),
#  ('mr', 2508),
#  ('simply', 2505),
#  ('picture', 2499),
#  ('children', 2499),
#  ('face', 2493),
#  ('keep', 2493),
#  ('friend', 2493),
#  ('dark', 2490),
#  ('overall', 2484),
#  ('certainly', 2484),
#  ('minutes', 2481),
#  ('wasn', 2472),
#  ('history', 2466),
#  ('finally', 2460),
#  ('couple', 2448),
#  ('against', 2445),
#  ('son', 2427),
#  ('understand', 2424),
#  ('lost', 2421),
#  ('michael', 2415),
#  ('else', 2403),
#  ('throughout', 2394),
#  ('fans', 2391),
#  ('city', 2376),
#  ('reason', 2367),
#  ('written', 2361),
#  ('production', 2361),
#  ('several', 2352),
#  ('school', 2349),
#  ('based', 2343),
#  ('rest', 2343),
#  ('try', 2340),
#  ('dead', 2328),
#  ('hope', 2325),
#  ('strong', 2304),
#  ('white', 2295),
#  ('tell', 2277),
#  ('itself', 2274),
#  ('half', 2259),
#  ('person', 2247),
#  ('sometimes', 2238),
#  ('past', 2232),
#  ('start', 2232),
#  ('genre', 2229),
#  ('beginning', 2217),
#  ('final', 2217),
#  ('town', 2214),
#  ('art', 2202),
#  ('humor', 2196),
#  ('game', 2196),
#  ('yes', 2193),
#  ('idea', 2193),
#  ('late', 2190),
#  ('becomes', 2187),
#  ('despite', 2187),
#  ('able', 2178),
#  ('case', 2178),
#  ('money', 2169),
#  ('child', 2163),
#  ('completely', 2163),
#  ('side', 2157),
#  ('camera', 2148),
#  ('getting', 2142),
#  ('instead', 2136),
#  ('soon', 2106),
#  ('under', 2100),
#  ('viewer', 2097),
#  ('age', 2091),
#  ('days', 2088),
#  ('stories', 2088),
#  ('felt', 2082),
#  ('simple', 2082),
#  ('roles', 2079),
#  ('video', 2064),
#  ('name', 2049),
#  ('either', 2049),
#  ('doing', 2031),
#  ('turns', 2022),
#  ('wants', 2013),
#  ('close', 2013),
#  ('title', 2007),
#  ('wrong', 2004),
#  ('went', 1998),
#  ('james', 1995),
#  ('evil', 1977),
#  ('budget', 1971),
#  ('episodes', 1971),
#  ('relationship', 1965),
#  ('fantastic', 1959),
#  ('piece', 1959),
#  ('david', 1953),
#  ('turn', 1944),
#  ('murder', 1938),
#  ('parts', 1935),
#  ('brother', 1932),
#  ('absolutely', 1929),
#  ('head', 1929),
#  ('experience', 1926),
#  ('eyes', 1923),
#  ('sex', 1914),
#  ('direction', 1911),
#  ('called', 1911),
#  ('directed', 1908),
#  ('lines', 1902),
#  ('behind', 1899),
#  ('sort', 1896),
#  ('actress', 1893),
#  ('lead', 1890),
#  ('oscar', 1884),
#  ('including', 1881),
#  ('example', 1881),
#  ('known', 1875),
#  ('musical', 1875),
#  ('chance', 1863),
#  ('score', 1860),
#  ('already', 1857),
#  ('feeling', 1857),
#  ('hit', 1857),
#  ('voice', 1845),
#  ('moment', 1836),
#  ('living', 1836),
#  ('low', 1830),
#  ('supporting', 1830),
#  ('ago', 1827),
#  ('themselves', 1824),
#  ('reality', 1815),
#  ('hilarious', 1815),
#  ('jack', 1812),
#  ('told', 1809),
#  ('hand', 1803),
#  ('quality', 1800),
#  ('moving', 1800),
#  ('dialogue', 1800),
#  ('song', 1797),
#  ('happy', 1797),
#  ('matter', 1794),
#  ('paul', 1794),
#  ('light', 1782),
#  ('future', 1779),
#  ('entire', 1776),
#  ('finds', 1773),
#  ('gave', 1767),
#  ('laugh', 1761),
#  ('released', 1758),
#  ('expect', 1752),
#  ('fight', 1743),
#  ('particularly', 1740),
#  ('cinematography', 1737),
#  ('police', 1737),
#  ('whose', 1734),
#  ('type', 1734),
#  ('sound', 1734),
#  ('view', 1719),
#  ('enjoyable', 1719),
#  ('number', 1716),
#  ('romantic', 1716),
#  ('husband', 1716),
#  ('daughter', 1716),
#  ('documentary', 1713),
#  ('self', 1710),
#  ('superb', 1707),
#  ('modern', 1707),
#  ('took', 1707),
#  ('robert', 1707),
#  ('mean', 1698),
#  ('shown', 1689),
#  ('coming', 1683),
#  ('important', 1680),
#  ('king', 1677),
#  ('leave', 1677),
#  ('change', 1674),
#  ('somewhat', 1665),
#  ('wanted', 1665),
#  ('tells', 1662),
#  ('events', 1656),
#  ('run', 1656),
#  ('career', 1656),
#  ('country', 1656),
#  ('heard', 1650),
#  ('season', 1650),
#  ('greatest', 1647),
#  ('girls', 1647),
#  ('etc', 1641),
#  ('care', 1638),
#  ('starts', 1635),
#  ('english', 1626),
#  ('killer', 1623),
#  ('tale', 1620),
#  ('guys', 1620),
#  ('totally', 1620),
#  ('animation', 1620),
#  ('usual', 1617),
#  ('miss', 1605),
#  ('opinion', 1605),
#  ('easy', 1593),
#  ('violence', 1593),
#  ('songs', 1590),
#  ('british', 1584),
#  ('says', 1578),
#  ('realistic', 1575),
#  ('writing', 1572),
#  ('writer', 1566),
#  ('act', 1566),
#  ('comic', 1563),
#  ('thriller', 1557),
#  ('television', 1551),
#  ('power', 1548),
#  ('ones', 1545),
#  ('kid', 1542),
#  ('york', 1539),
#  ('novel', 1539),
#  ('alone', 1536),
#  ('problem', 1536),
#  ('attention', 1527),
#  ('involved', 1524),
#  ('kill', 1521),
#  ('extremely', 1521),
#  ('seemed', 1518),
#  ('hero', 1515),
#  ('french', 1515),
#  ('rock', 1512),
#  ('stuff', 1503),
#  ('wish', 1497),
#  ('begins', 1494),
#  ('taken', 1491),
#  ('sad', 1491),
#  ('ways', 1488),
#  ('richard', 1485),
#  ('knows', 1482),
#  ('atmosphere', 1479),
#  ('similar', 1473),
#  ('surprised', 1473),
#  ('taking', 1473),
#  ('car', 1473),
#  ('george', 1470),
#  ('perfectly', 1470),
#  ('across', 1467),
#  ('team', 1467),
#  ('eye', 1467),
#  ('sequence', 1467),
#  ('room', 1464),
#  ('due', 1464),
#  ('among', 1464),
#  ('serious', 1464),
#  ('powerful', 1464),
#  ('strange', 1461),
#  ('order', 1461),
#  ('cannot', 1461),
#  ('b', 1461),
#  ('beauty', 1458),
#  ('famous', 1455),
#  ('happened', 1452),
#  ('tries', 1452),
#  ('herself', 1452),
#  ('myself', 1452),
#  ('class', 1449),
#  ('four', 1446),
#  ('cool', 1443),
#  ('release', 1437),
#  ('anyway', 1437),
#  ('theme', 1437),
#  ('opening', 1434),
#  ('entertainment', 1431),
#  ('slow', 1425),
#  ('ends', 1425),
#  ('unique', 1425),
#  ('exactly', 1425),
#  ('easily', 1422),
#  ('level', 1422),
#  ('o', 1422),
#  ('red', 1422),
#  ('interest', 1416),
#  ('happen', 1413),
#  ('crime', 1410),
#  ('viewing', 1404),
#  ('sets', 1401),
#  ('memorable', 1401),
#  ('stop', 1398),
#  ('group', 1398),
#  ('problems', 1389),
#  ('dance', 1389),
#  ('working', 1389),
#  ('sister', 1389),
#  ('message', 1389),
#  ('knew', 1386),
#  ('mystery', 1383),
#  ('nature', 1383),
#  ('bring', 1380),
#  ('believable', 1377),
#  ('thinking', 1377),
#  ('brought', 1377),
#  ('mostly', 1374),
#  ('disney', 1371),
#  ('couldn', 1371),
#  ('society', 1368),
#  ('lady', 1365),
#  ('within', 1365),
#  ('blood', 1362),
#  ('parents', 1359),
#  ('upon', 1359),
#  ('viewers', 1359),
#  ('meets', 1356),
#  ('form', 1356),
#  ('peter', 1356),
#  ('tom', 1356),
#  ('usually', 1356),
#  ('soundtrack', 1356),
#  ('local', 1350),
#  ('certain', 1344),
#  ('follow', 1344),
#  ('whether', 1341),
#  ('possible', 1338),
#  ('emotional', 1335),
#  ('killed', 1332),
#  ('above', 1332),
#  ('de', 1332),
#  ('god', 1329),
#  ('middle', 1329),
#  ('needs', 1326),
#  ('happens', 1326),
#  ('flick', 1326),
#  ('masterpiece', 1323),
#  ('period', 1320),
#  ('major', 1320),
#  ('named', 1317),
#  ('haven', 1317),
#  ('particular', 1314),
#  ('th', 1314),
#  ('earth', 1311),
#  ('feature', 1311),
#  ('stand', 1308),
#  ('words', 1305),
#  ('typical', 1305),
#  ('elements', 1299),
#  ('obviously', 1299),
#  ('romance', 1293),
#  ('jane', 1290),
#  ('yourself', 1281),
#  ('showing', 1281),
#  ('brings', 1278),
#  ('fantasy', 1278),
#  ('guess', 1269),
#  ('america', 1269),
#  ('unfortunately', 1266),
#  ('huge', 1266),
#  ('indeed', 1263),
#  ('running', 1263),
#  ('talent', 1260),
#  ('stage', 1257),
#  ('started', 1254),
#  ('leads', 1251),
#  ('sweet', 1251),
#  ('japanese', 1251),
#  ('poor', 1248),
#  ('deal', 1248),
#  ('incredible', 1239),
#  ('personal', 1239),
#  ('fast', 1236),
#  ('became', 1230),
#  ('deep', 1230),
#  ('hours', 1227),
#  ('giving', 1224),
#  ('nearly', 1224),
#  ('dream', 1224),
#  ('clearly', 1221),
#  ('turned', 1221),
#  ('obvious', 1218),
#  ('near', 1218),
#  ('cut', 1215),
#  ('surprise', 1215),
#  ('era', 1212),
#  ('body', 1212),
#  ('hour', 1209),
#  ('female', 1209),
#  ('five', 1209),
#  ('note', 1197),
#  ('learn', 1194),
#  ('truth', 1194),
#  ('except', 1191),
#  ('feels', 1191),
#  ('match', 1191),
#  ('tony', 1191),
#  ('filmed', 1182),
#  ('clear', 1182),
#  ('complete', 1182),
#  ('street', 1179),
#  ('eventually', 1179),
#  ('keeps', 1179),
#  ('older', 1179),
#  ('lots', 1179),
#  ('buy', 1176),
#  ('william', 1173),
#  ('stewart', 1173),
#  ('fall', 1170),
#  ('joe', 1170),
#  ('meet', 1170),
#  ('unlike', 1167),
#  ('talking', 1167),
#  ('shots', 1167),
#  ('rating', 1167),
#  ('difficult', 1167),
#  ('dramatic', 1164),
#  ('means', 1164),
#  ('situation', 1158),
#  ('wonder', 1158),
#  ('present', 1158),
#  ('appears', 1158),
#  ('subject', 1158),
#  ('comments', 1155),
#  ('general', 1149),
#  ('sequences', 1149),
#  ('lee', 1149),
#  ('points', 1146),
#  ('earlier', 1146),
#  ('gone', 1137),
#  ('check', 1137),
#  ('suspense', 1134),
#  ('recommended', 1134),
#  ('ten', 1134),
#  ('third', 1131),
#  ('business', 1131),
#  ('talk', 1125),
#  ('leaves', 1125),
#  ('beyond', 1125),
#  ('portrayal', 1122),
#  ('beautifully', 1119),
#  ('single', 1116),
#  ('bill', 1116),
#  ('plenty', 1113),
#  ('word', 1113),
#  ('whom', 1110),
#  ('falls', 1110),
#  ('scary', 1107),
#  ('non', 1107),
#  ('figure', 1107),
#  ('battle', 1107),
#  ('using', 1104),
#  ('return', 1104),
#  ('doubt', 1101),
#  ('add', 1101),
#  ('hear', 1098),
#  ('solid', 1098),
#  ('success', 1098),
#  ('jokes', 1095),
#  ('oh', 1095),
#  ('touching', 1095),
#  ('political', 1095),
#  ('hell', 1092),
#  ('awesome', 1092),
#  ('boys', 1092),
#  ('sexual', 1086),
#  ('recently', 1086),
#  ('dog', 1086),
#  ('please', 1083),
#  ('wouldn', 1083),
#  ('straight', 1083),
#  ('features', 1083),
#  ('forget', 1080),
#  ('setting', 1080),
#  ('lack', 1080),
#  ('married', 1077),
#  ('mark', 1077),
#  ('social', 1071),
#  ('interested', 1068),
#  ('adventure', 1068),
#  ('actual', 1065),
#  ('terrific', 1065),
#  ('sees', 1065),
#  ('brothers', 1065),
#  ('move', 1062),
#  ('call', 1062),
#  ('various', 1059),
#  ('theater', 1059),
#  ('dr', 1059),
#  ('animated', 1056),
#  ('western', 1053),
#  ('baby', 1050),
#  ('space', 1050),
#  ('leading', 1044),
#  ('disappointed', 1044),
#  ('portrayed', 1038),
#  ('aren', 1038),
#  ('screenplay', 1035),
#  ('smith', 1035),
#  ('towards', 1032),
#  ('hate', 1032),
#  ('noir', 1029),
#  ('outstanding', 1026),
#  ('decent', 1026),
#  ('kelly', 1026),
#  ('directors', 1023),
#  ('journey', 1023),
#  ('none', 1020),
#  ('looked', 1020),
#  ('effective', 1020),
#  ('storyline', 1017),
#  ('caught', 1017),
#  ('sci', 1017),
#  ('fi', 1017),
#  ('cold', 1017),
#  ('mary', 1017),
#  ('rich', 1014),
#  ('charming', 1014),
#  ('popular', 1011),
#  ('rare', 1011),
#  ('manages', 1011),
#  ('harry', 1011),
#  ('spirit', 1008),
#  ('appreciate', 1005),
#  ('open', 1005),
#  ('moves', 1002),
#  ('basically', 1002),
#  ('acted', 1002),
#  ('inside', 999),
#  ('boring', 999),
#  ('century', 999),
#  ('mention', 999),
#  ('deserves', 999),
#  ('subtle', 999),
#  ('pace', 999),
#  ('familiar', 996),
#  ('background', 996),
#  ('ben', 993),
#  ('creepy', 990),
#  ('supposed', 990),
#  ('secret', 987),
#  ('die', 984),
#  ('jim', 984),
#  ('question', 981),
#  ('effect', 981),
#  ('natural', 981),
#  ('impressive', 978),
#  ('rate', 978),
#  ('language', 978),
#  ('saying', 975),
#  ('intelligent', 975),
#  ('telling', 972),
#  ('realize', 972),
#  ('material', 972),
#  ('scott', 972),
#  ('singing', 969),
#  ('dancing', 966),
#  ('visual', 963),
#  ('adult', 963),
#  ('imagine', 963),
#  ('kept', 960),
#  ('office', 960),
#  ('uses', 957),
#  ('pure', 954),
#  ('wait', 954),
#  ('stunning', 954),
#  ('review', 951),
#  ('previous', 951),
#  ('copy', 951),
#  ('seriously', 951),
#  ('reading', 948),
#  ('create', 948),
#  ('hot', 948),
#  ('created', 948),
#  ('magic', 948),
#  ('somehow', 948),
#  ('stay', 945),
#  ('attempt', 945),
#  ('escape', 945),
#  ('crazy', 945),
#  ('air', 945),
#  ('frank', 945),
#  ('hands', 942),
#  ('filled', 939),
#  ('expected', 936),
#  ('average', 936),
#  ('surprisingly', 936),
#  ('complex', 933),
#  ('quickly', 930),
#  ('successful', 930),
#  ('studio', 930),
#  ('plus', 927),
#  ('male', 927),
#  ('co', 921),
#  ('images', 918),
#  ('casting', 918),
#  ('following', 918),
#  ('minute', 918),
#  ('exciting', 918),
#  ('members', 915),
#  ('follows', 915),
#  ('themes', 915),
#  ('german', 915),
#  ('reasons', 915),
#  ('e', 915),
#  ('touch', 912),
#  ('edge', 912),
#  ('free', 912),
#  ('cute', 912),
#  ('genius', 912),
#  ('outside', 909),
#  ('reviews', 906),
#  ('admit', 906),
#  ('ok', 906),
#  ('younger', 906),
#  ('fighting', 903),
#  ('odd', 903),
#  ('master', 903),
#  ('recent', 900),
#  ('thanks', 900),
#  ('break', 900),
#  ('comment', 900),
#  ('apart', 897),
#  ('emotions', 894),
#  ('lovely', 894),
#  ('begin', 894),
#  ('doctor', 891),
#  ('party', 891),
#  ('italian', 891),
#  ('la', 888),
#  ('missed', 888),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 1122924),
#  ('.', 502614),
#  ('the', 490167),
#  ('a', 237963),
#  ('and', 223155),
#  ('of', 207027),
#  ('to', 206922),
#  ('br', 157911),
#  ('is', 150249),
#  ('it', 144981),
#  ('i', 140640),
#  ('in', 131259),
#  ('this', 122760),
#  ('that', 112845),
#  ('s', 94638),
#  ('was', 78873),
#  ('movie', 74895),
#  ('for', 65781),
#  ('but', 65343),
#  ('with', 62634),
#  ('as', 61875),
#  ('t', 61083),
#  ('film', 57654),
#  ('you', 52647),
#  ('on', 51576),
#  ('not', 49062),
#  ('have', 45432),
#  ('are', 43869),
#  ('be', 43623),
#  ('he', 41568),
#  ('one', 39402),
#  ('they', 39033),
#  ('at', 36837),
#  ('his', 36441),
#  ('all', 36108),
#  ('so', 34389),
#  ('like', 33714),
#  ('there', 32325),
#  ('just', 31857),
#  ('by', 31647),
#  ('or', 30816),
#  ('an', 30798),
#  ('who', 29907),
#  ('from', 29193),
#  ('if', 28554),
#  ('about', 27183),
#  ('out', 26937),
#  ('what', 25266),
#  ('some', 24918),
#  ('no', 24429),
#  ('her', 23841),
#  ('even', 23061),
#  ('can', 22959),
#  ('has', 22812),
#  ('good', 22269),
#  ('bad', 22203),
#  ('would', 21108),
#  ('up', 20910),
#  ('only', 20343),
#  ('more', 20190),
#  ('when', 20178),
#  ('she', 19332),
#  ('really', 18786),
#  ('time', 18627),
#  ('had', 18426),
#  ('my', 18045),
#  ('were', 18003),
#  ('which', 17340),
#  ('very', 17292),
#  ('me', 16818),
#  ('see', 16356),
#  ('don', 16008),
#  ('we', 15984),
#  ('their', 15834),
#  ('do', 15708),
#  ('story', 15624),
#  ('than', 15549),
#  ('been', 15300),
#  ('much', 15234),
#  ('get', 15111),
#  ('because', 14898),
#  ('people', 14418),
#  ('then', 14283),
#  ('make', 14166),
#  ('how', 14064),
#  ('could', 14058),
#  ('any', 13974),
#  ('into', 13701),
#  ('made', 13623),
#  ('first', 12918),
#  ('other', 12915),
#  ('well', 12762),
#  ('too', 12522),
#  ('them', 12495),
#  ('plot', 12462),
#  ('movies', 12240),
#  ('acting', 12168),
#  ('will', 11979),
#  ('way', 11967),
#  ('most', 11757),
#  ('him', 11574),
#  ('after', 11514),
#  ('its', 10965),
#  ('think', 10929),
#  ('also', 10824),
#  ('characters', 10800),
#  ('off', 10701),
#  ('watch', 10650),
#  ('character', 10518),
#  ('did', 10518),
#  ('why', 10389),
#  ('being', 10179),
#  ('better', 10074),
#  ('know', 10002),
#  ('over', 9948),
#  ('seen', 9795),
#  ('ever', 9789),
#  ('never', 9777),
#  ('your', 9699),
#  ('where', 9657),
#  ('two', 9519),
#  ('little', 9288),
#  ('films', 9231),
#  ('here', 9081),
#  ('m', 9000),
#  ('nothing', 8970),
#  ('say', 8946),
#  ('end', 8862),
#  ('something', 8826),
#  ('should', 8760),
#  ('many', 8727),
#  ('does', 8613),
#  ('thing', 8598),
#  ('show', 8586),
#  ('ve', 8487),
#  ('scene', 8448),
#  ('scenes', 8355),
#  ('these', 8172),
#  ('go', 8151),
#  ('didn', 7938),
#  ('great', 7920),
#  ('watching', 7920),
#  ('re', 7860),
#  ('doesn', 7803),
#  ('through', 7680),
#  ('such', 7632),
#  ('man', 7548),
#  ('worst', 7440),
#  ('actually', 7347),
#  ('actors', 7311),
#  ('life', 7287),
#  ('back', 7272),
#  ('while', 7254),
#  ('director', 7215),
#  ('funny', 7008),
#  ('going', 6957),
#  ('still', 6849),
#  ('another', 6762),
#  ('look', 6741),
#  ('now', 6711),
#  ('old', 6645),
#  ('those', 6636),
#  ('real', 6510),
#  ('few', 6474),
#  ('love', 6456),
#  ('horror', 6450),
#  ('before', 6441),
#  ('want', 6423),
#  ('minutes', 6378),
#  ('pretty', 6345),
#  ('best', 6282),
#  ('though', 6273),
#  ('same', 6243),
#  ('script', 6222),
#  ('work', 6081),
#  ('every', 6075),
#  ('seems', 6069),
#  ('least', 6033),
#  ('enough', 5991),
#  ('down', 5964),
#  ('original', 5949),
#  ('guy', 5892),
#  ('got', 5856),
#  ('around', 5829),
#  ('part', 5826),
#  ('lot', 5676),
#  ('anything', 5622),
#  ('find', 5580),
#  ('new', 5562),
#  ('again', 5547),
#  ('isn', 5547),
#  ('point', 5535),
#  ('things', 5517),
#  ('fact', 5517),
#  ('give', 5469),
#  ('makes', 5442),
#  ('take', 5400),
#  ('thought', 5394),
#  ('d', 5310),
#  ('whole', 5304),
#  ('long', 5283),
#  ('years', 5277),
#  ('however', 5220),
#  ('gets', 5142),
#  ('making', 5085),
#  ('cast', 5082),
#  ('big', 4986),
#  ('might', 4974),
#  ('interesting', 4944),
#  ('money', 4914),
#  ('us', 4884),
#  ('right', 4875),
#  ('far', 4857),
#  ('quite', 4788),
#  ('without', 4785),
#  ('come', 4785),
#  ('almost', 4722),
#  ('ll', 4701),
#  ('action', 4698),
#  ('awful', 4671),
#  ('kind', 4617),
#  ('reason', 4602),
#  ('am', 4590),
#  ('looks', 4584),
#  ('must', 4566),
#  ('done', 4530),
#  ('comedy', 4512),
#  ('someone', 4470),
#  ('trying', 4458),
#  ('wasn', 4452),
#  ('poor', 4443),
#  ('boring', 4434),
#  ('instead', 4434),
#  ('saw', 4425),
#  ('away', 4407),
#  ('girl', 4389),
#  ('probably', 4332),
#  ('believe', 4302),
#  ('sure', 4299),
#  ('looking', 4290),
#  ('stupid', 4284),
#  ('anyone', 4254),
#  ('times', 4218),
#  ('maybe', 4212),
#  ('world', 4212),
#  ('rather', 4182),
#  ('terrible', 4173),
#  ('may', 4170),
#  ('last', 4170),
#  ('since', 4164),
#  ('let', 4155),
#  ('tv', 4146),
#  ('hard', 4122),
#  ('between', 4122),
#  ('waste', 4074),
#  ('woman', 4068),
#  ('feel', 4062),
#  ('effects', 4044),
#  ('half', 4023),
#  ('own', 3999),
#  ('young', 3951),
#  ('music', 3948),
#  ('idea', 3936),
#  ('sense', 3918),
#  ('bit', 3894),
#  ('having', 3840),
#  ('book', 3834),
#  ('found', 3801),
#  ('put', 3789),
#  ('series', 3789),
#  ('goes', 3768),
#  ('worse', 3747),
#  ('said', 3690),
#  ('comes', 3672),
#  ('role', 3666),
#  ('main', 3660),
#  ('else', 3597),
#  ('everything', 3591),
#  ('yet', 3588),
#  ('low', 3567),
#  ('screen', 3564),
#  ('supposed', 3558),
#  ('actor', 3555),
#  ('either', 3549),
#  ('budget', 3537),
#  ('ending', 3537),
#  ('audience', 3534),
#  ('set', 3531),
#  ('family', 3510),
#  ('left', 3507),
#  ('completely', 3504),
#  ('both', 3474),
#  ('wrong', 3465),
#  ('always', 3453),
#  ('course', 3444),
#  ('place', 3444),
#  ('seem', 3441),
#  ('watched', 3426),
#  ('day', 3396),
#  ('simply', 3390),
#  ('shot', 3378),
#  ('mean', 3351),
#  ('special', 3306),
#  ('dead', 3303),
#  ('three', 3282),
#  ('house', 3255),
#  ('oh', 3252),
#  ('night', 3249),
#  ('read', 3246),
#  ('less', 3201),
#  ('high', 3198),
#  ('year', 3192),
#  ('camera', 3183),
#  ('worth', 3171),
#  ('our', 3168),
#  ('try', 3153),
#  ('horrible', 3138),
#  ('sex', 3138),
#  ('video', 3129),
#  ('black', 3117),
#  ('although', 3108),
#  ('couldn', 3108),
#  ('once', 3099),
#  ('rest', 3066),
#  ('dvd', 3063),
#  ('line', 3054),
#  ('played', 3051),
#  ('fun', 3021),
#  ('during', 3018),
#  ('production', 3009),
#  ('everyone', 3006),
#  ('play', 2979),
#  ('mind', 2970),
#  ('version', 2967),
#  ('kids', 2967),
#  ('seeing', 2964),
#  ('american', 2940),
#  ('given', 2934),
#  ('used', 2907),
#  ('performance', 2904),
#  ('especially', 2889),
#  ('together', 2889),
#  ('tell', 2877),
#  ('women', 2874),
#  ('start', 2868),
#  ('need', 2865),
#  ('second', 2859),
#  ('takes', 2850),
#  ('each', 2850),
#  ('wife', 2832),
#  ('dialogue', 2826),
#  ('use', 2820),
#  ('problem', 2814),
#  ('star', 2802),
#  ('unfortunately', 2793),
#  ('himself', 2787),
#  ('doing', 2778),
#  ('death', 2766),
#  ('name', 2763),
#  ('lines', 2757),
#  ('killer', 2742),
#  ('getting', 2739),
#  ('help', 2715),
#  ('couple', 2706),
#  ('fan', 2706),
#  ('head', 2694),
#  ('crap', 2685),
#  ('guess', 2664),
#  ('piece', 2652),
#  ('nice', 2640),
#  ('different', 2634),
#  ('school', 2628),
#  ('later', 2625),
#  ('entire', 2607),
#  ('shows', 2580),
#  ('next', 2574),
#  ('john', 2574),
#  ('short', 2571),
#  ('seemed', 2571),
#  ('hollywood', 2550),
#  ('home', 2544),
#  ('true', 2538),
#  ('person', 2538),
#  ('absolutely', 2526),
#  ('sort', 2520),
#  ('care', 2517),
#  ('understand', 2508),
#  ('plays', 2505),
#  ('felt', 2502),
#  ('written', 2487),
#  ('title', 2484),
#  ('men', 2466),
#  ('until', 2463),
#  ('flick', 2448),
#  ('decent', 2445),
#  ('face', 2442),
#  ('friends', 2430),
#  ('stars', 2421),
#  ('job', 2421),
#  ('case', 2421),
#  ('itself', 2412),
#  ('yes', 2403),
#  ('perhaps', 2400),
#  ('went', 2391),
#  ('wanted', 2391),
#  ('called', 2388),
#  ('annoying', 2385),
#  ('ridiculous', 2370),
#  ('tries', 2370),
#  ('laugh', 2364),
#  ('evil', 2361),
#  ('along', 2358),
#  ('top', 2355),
#  ('hour', 2352),
#  ('full', 2349),
#  ('came', 2340),
#  ('writing', 2340),
#  ('keep', 2310),
#  ('totally', 2301),
#  ('playing', 2298),
#  ('god', 2295),
#  ('won', 2292),
#  ('guys', 2289),
#  ('already', 2286),
#  ('gore', 2271),
#  ('direction', 2244),
#  ('save', 2238),
#  ('lost', 2235),
#  ('example', 2232),
#  ('sound', 2226),
#  ('war', 2223),
#  ('attempt', 2205),
#  ('car', 2199),
#  ('except', 2199),
#  ('moments', 2196),
#  ('blood', 2196),
#  ('obviously', 2190),
#  ('act', 2187),
#  ('remember', 2184),
#  ('kill', 2181),
#  ('truly', 2178),
#  ('white', 2178),
#  ('father', 2178),
#  ('b', 2175),
#  ('thinking', 2160),
#  ('ok', 2148),
#  ('finally', 2148),
#  ('turn', 2133),
#  ('quality', 2103),
#  ('lack', 2094),
#  ('style', 2082),
#  ('wouldn', 2079),
#  ('cheap', 2073),
#  ('none', 2070),
#  ('kid', 2058),
#  ('please', 2058),
#  ('boy', 2055),
#  ('seriously', 2052),
#  ('lead', 2040),
#  ('dull', 2031),
#  ('children', 2028),
#  ('starts', 2025),
#  ('stuff', 2019),
#  ('hope', 2016),
#  ('looked', 2010),
#  ('recommend', 2007),
#  ('under', 2004),
#  ('run', 2001),
#  ('killed', 2001),
#  ('enjoy', 1998),
#  ('others', 1998),
#  ('etc', 1989),
#  ('myself', 1989),
#  ('beginning', 1986),
#  ('girls', 1986),
#  ('against', 1986),
#  ('obvious', 1980),
#  ('small', 1980),
#  ('hell', 1977),
#  ('slow', 1971),
#  ('hand', 1968),
#  ('wonder', 1956),
#  ('lame', 1956),
#  ('becomes', 1953),
#  ('picture', 1953),
#  ('based', 1950),
#  ('early', 1944),
#  ('behind', 1938),
#  ('poorly', 1932),
#  ('avoid', 1926),
#  ('apparently', 1920),
#  ('complete', 1920),
#  ('happens', 1917),
#  ('anyway', 1914),
#  ('classic', 1911),
#  ('several', 1908),
#  ('despite', 1905),
#  ('certainly', 1905),
#  ('episode', 1905),
#  ('often', 1893),
#  ('cut', 1890),
#  ('writer', 1890),
#  ('mother', 1884),
#  ('predictable', 1884),
#  ('gave', 1884),
#  ('become', 1881),
#  ('close', 1875),
#  ('fans', 1872),
#  ('saying', 1863),
#  ('scary', 1857),
#  ('stop', 1854),
#  ('live', 1854),
#  ('wants', 1851),
#  ('self', 1845),
#  ('mr', 1836),
#  ('jokes', 1833),
#  ('friend', 1833),
#  ('cannot', 1830),
#  ('overall', 1827),
#  ('cinema', 1812),
#  ('child', 1809),
#  ('silly', 1803),
#  ('beautiful', 1788),
#  ('human', 1785),
#  ('expect', 1782),
#  ('liked', 1779),
#  ('happened', 1776),
#  ('bunch', 1770),
#  ('entertaining', 1770),
#  ('actress', 1764),
#  ('final', 1764),
#  ('says', 1752),
#  ('performances', 1752),
#  ('turns', 1731),
#  ('humor', 1731),
#  ('themselves', 1728),
#  ('eyes', 1728),
#  ('hours', 1722),
#  ('happen', 1719),
#  ('basically', 1716),
#  ('days', 1716),
#  ('running', 1713),
#  ('involved', 1707),
#  ('disappointed', 1707),
#  ('call', 1707),
#  ('directed', 1704),
#  ('group', 1704),
#  ('fight', 1701),
#  ('daughter', 1698),
#  ('talking', 1698),
#  ('body', 1698),
#  ('badly', 1695),
#  ('sorry', 1695),
#  ('throughout', 1689),
#  ('viewer', 1689),
#  ('yourself', 1686),
#  ('extremely', 1686),
#  ('interest', 1683),
#  ('heard', 1683),
#  ('violence', 1683),
#  ('shots', 1677),
#  ('side', 1671),
#  ('word', 1668),
#  ('art', 1665),
#  ('possible', 1662),
#  ('dark', 1653),
#  ('game', 1653),
#  ('hero', 1650),
#  ('alone', 1647),
#  ('son', 1641),
#  ('type', 1641),
#  ('leave', 1641),
#  ('gives', 1638),
#  ('parts', 1638),
#  ('single', 1638),
#  ('started', 1635),
#  ('female', 1629),
#  ('rating', 1623),
#  ('mess', 1623),
#  ('voice', 1623),
#  ('aren', 1620),
#  ('town', 1620),
#  ('drama', 1614),
#  ('definitely', 1611),
#  ('unless', 1608),
#  ('review', 1602),
#  ('effort', 1599),
#  ('weak', 1599),
#  ('able', 1599),
#  ('took', 1593),
#  ('non', 1590),
#  ('five', 1590),
#  ('matter', 1587),
#  ('usually', 1587),
#  ('michael', 1584),
#  ('feeling', 1578),
#  ('huge', 1569),
#  ('sequel', 1566),
#  ('soon', 1563),
#  ('exactly', 1560),
#  ('past', 1557),
#  ('turned', 1554),
#  ('police', 1554),
#  ('tried', 1545),
#  ('middle', 1539),
#  ('talent', 1539),
#  ('genre', 1536),
#  ('zombie', 1530),
#  ('ends', 1527),
#  ('history', 1527),
#  ('straight', 1509),
#  ('opening', 1503),
#  ('serious', 1503),
#  ('coming', 1503),
#  ('moment', 1500),
#  ('lives', 1497),
#  ('sad', 1497),
#  ('dialog', 1494),
#  ('particularly', 1494),
#  ('editing', 1479),
#  ('clearly', 1476),
#  ('beyond', 1473),
#  ('earth', 1473),
#  ('taken', 1470),
#  ('cool', 1470),
#  ('level', 1467),
#  ('dumb', 1467),
#  ('okay', 1464),
#  ('major', 1461),
#  ('fast', 1455),
#  ('premise', 1455),
#  ('joke', 1452),
#  ('stories', 1452),
#  ('wasted', 1449),
#  ('minute', 1449),
#  ('across', 1446),
#  ('mostly', 1446),
#  ('rent', 1446),
#  ('late', 1443),
#  ('falls', 1443),
#  ('fails', 1443),
#  ('mention', 1434),
#  ('theater', 1425),
#  ('stay', 1416),
#  ('sometimes', 1416),
#  ('hit', 1404),
#  ('talk', 1401),
#  ('fine', 1401),
#  ('die', 1398),
#  ('storyline', 1395),
#  ('pointless', 1395),
#  ('taking', 1392),
#  ('order', 1386),
#  ('brother', 1383),
#  ('whatever', 1380),
#  ('told', 1380),
#  ('wish', 1374),
#  ('room', 1368),
#  ('career', 1365),
#  ('appears', 1365),
#  ('write', 1365),
#  ('known', 1362),
#  ('husband', 1362),
#  ('living', 1353),
#  ('sit', 1350),
#  ('ten', 1350),
#  ('words', 1347),
#  ('monster', 1344),
#  ('chance', 1344),
#  ('hate', 1332),
#  ('novel', 1332),
#  ('add', 1329),
#  ('english', 1329),
#  ('somehow', 1323),
#  ('strange', 1320),
#  ('imdb', 1314),
#  ('actual', 1314),
#  ('total', 1311),
#  ('material', 1311),
#  ('killing', 1311),
#  ('ones', 1311),
#  ('knew', 1308),
#  ('king', 1302),
#  ('number', 1302),
#  ('using', 1299),
#  ('lee', 1293),
#  ('power', 1293),
#  ('shown', 1293),
#  ('works', 1293),
#  ('giving', 1293),
#  ('points', 1290),
#  ('possibly', 1290),
#  ('kept', 1290),
#  ('four', 1287),
#  ('local', 1281),
#  ('usual', 1278),
#  ('including', 1275),
#  ('problems', 1272),
#  ('ago', 1272),
#  ('opinion', 1272),
#  ('nudity', 1269),
#  ('age', 1266),
#  ('due', 1263),
#  ('roles', 1260),
#  ('writers', 1257),
#  ('decided', 1257),
#  ('near', 1254),
#  ('flat', 1254),
#  ('easily', 1254),
#  ('murder', 1251),
#  ('experience', 1251),
#  ('reviews', 1248),
#  ('imagine', 1245),
#  ('feels', 1239),
#  ('plain', 1233),
#  ('somewhat', 1233),
#  ('class', 1230),
#  ('score', 1230),
#  ('song', 1227),
#  ('bring', 1227),
#  ('whether', 1227),
#  ('otherwise', 1224),
#  ('whose', 1224),
#  ('average', 1224),
#  ('pathetic', 1221),
#  ('nearly', 1221),
#  ('knows', 1221),
#  ('zombies', 1221),
#  ('cinematography', 1218),
#  ('cheesy', 1218),
#  ('upon', 1218),
#  ('city', 1215),
#  ('space', 1215),
#  ('credits', 1212),
#  ('james', 1209),
#  ('lots', 1209),
#  ('change', 1209),
#  ('entertainment', 1206),
#  ('nor', 1206),
#  ('wait', 1203),
#  ('released', 1200),
#  ('needs', 1197),
#  ('shame', 1194),
#  ('attention', 1188),
#  ('comments', 1182),
#  ('bored', 1179),
#  ('free', 1179),
#  ('lady', 1179),
#  ('expected', 1176),
#  ('needed', 1176),
#  ('clear', 1176),
#  ('view', 1173),
#  ('development', 1170),
#  ('check', 1170),
#  ('doubt', 1170),
#  ('figure', 1167),
#  ('mystery', 1167),
#  ('excellent', 1164),
#  ('garbage', 1164),
#  ('sequence', 1158),
#  ('television', 1158),
#  ('o', 1155),
#  ('sets', 1155),
#  ('laughable', 1152),
#  ('potential', 1152),
#  ('robert', 1146),
#  ('light', 1146),
#  ('country', 1146),
#  ('documentary', 1146),
#  ('reality', 1146),
#  ('general', 1143),
#  ('ask', 1143),
#  ('comic', 1140),
#  ('fall', 1140),
#  ('begin', 1140),
#  ('footage', 1137),
#  ('stand', 1137),
#  ('forced', 1137),
#  ('trash', 1137),
#  ('remake', 1137),
#  ('thriller', 1134),
#  ('songs', 1134),
#  ('gay', 1131),
#  ('within', 1131),
#  ('hardly', 1128),
#  ('above', 1125),
#  ('gone', 1125),
#  ('george', 1122),
#  ('means', 1119),
#  ('sounds', 1119),
#  ('directing', 1116),
#  ('move', 1116),
#  ('david', 1116),
#  ('buy', 1116),
#  ('rock', 1113),
#  ('forward', 1113),
#  ('important', 1113),
#  ('hot', 1110),
#  ('haven', 1110),
#  ('filmed', 1110),
#  ('british', 1110),
#  ('heart', 1107),
#  ('reading', 1107),
#  ('fake', 1107),
#  ('incredibly', 1104),
#  ('weird', 1104),
#  ('hear', 1104),
#  ('enjoyed', 1101),
#  ('hilarious', 1101),
#  ('cop', 1101),
#  ('musical', 1101),
#  ('message', 1098),
#  ('happy', 1098),
#  ('pay', 1098),
#  ('laughs', 1095),
#  ('box', 1095),
#  ('suspense', 1089),
#  ('sadly', 1089),
#  ('eye', 1086),
#  ('third', 1083),
#  ('similar', 1083),
#  ('named', 1083),
#  ('modern', 1080),
#  ('failed', 1077),
#  ('events', 1077),
#  ('forget', 1074),
#  ('question', 1074),
#  ('male', 1071),
#  ('finds', 1071),
#  ('perfect', 1068),
#  ('spent', 1065),
#  ('sister', 1065),
#  ('feature', 1062),
#  ('result', 1062),
#  ('comment', 1059),
#  ('girlfriend', 1059),
#  ('sexual', 1056),
#  ('attempts', 1053),
#  ('neither', 1053),
#  ('richard', 1053),
#  ('screenplay', 1050),
#  ('elements', 1050),
#  ('spoilers', 1047),
#  ('brain', 1044),
#  ('filmmakers', 1044),
#  ('showing', 1044),
#  ('miss', 1041),
#  ('dr', 1041),
#  ('christmas', 1041),
#  ('cover', 1035),
#  ('red', 1032),
#  ('sequences', 1032),
#  ('typical', 1029),
#  ('excuse', 1029),
#  ('crazy', 1026),
#  ('ideas', 1026),
#  ('baby', 1026),
#  ('loved', 1023),
#  ('meant', 1023),
#  ('worked', 1020),
#  ('fire', 1020),
#  ('unbelievable', 1017),
#  ('follow', 1017),
#  ('theme', 1011),
#  ('barely', 1008),
#  ('producers', 1008),
#  ('twist', 1008),
#  ('plus', 1008),
#  ('appear', 1008),
#  ('directors', 1005),
#  ('team', 1005),
#  ('viewers', 999),
#  ('leads', 996),
#  ('tom', 996),
#  ('slasher', 996),
#  ('wrote', 993),
#  ('villain', 993),
#  ('gun', 993),
#  ('working', 993),
#  ('island', 990),
#  ('strong', 990),
#  ('open', 990),
#  ('realize', 990),
#  ('positive', 987),
#  ('disappointing', 987),
#  ('yeah', 987),
#  ('quickly', 987),
#  ('weren', 984),
#  ('release', 984),
#  ('simple', 984),
#  ('honestly', 984),
#  ('eventually', 981),
#  ('period', 981),
#  ('tells', 981),
#  ('kills', 981),
#  ('doctor', 981),
#  ('nowhere', 978),
#  ('list', 978),
#  ('acted', 978),
#  ('herself', 978),
#  ('dog', 978),
#  ('walk', 975),
#  ('air', 972),
#  ('apart', 972),
#  ('makers', 969),
#  ('subject', 969),
#  ('learn', 966),
#  ('fi', 966),
#  ('sci', 957),
#  ('bother', 957),
#  ('admit', 957),
#  ('jack', 954),
#  ('disappointment', 954),
#  ('hands', 954),
#  ('note', 954),
#  ('certain', 951),
#  ('e', 951),
#  ('value', 951),
#  ('casting', 951),
#  ('grade', 948),
#  ('peter', 948),
#  ('suddenly', 945),
#  ('missing', 945),
#  ('form', 939),
#  ('stick', 939),
#  ('previous', 939),
#  ('break', 939),
#  ('soundtrack', 936),
#  ('surprised', 933),
#  ('front', 933),
#  ('expecting', 933),
#  ('parents', 930),
#  ('surprise', 930),
#  ('relationship', 930),
#  ('shoot', 927),
#  ('today', 927),
#  ('painful', 924),
#  ('ways', 924),
#  ('leaves', 924),
#  ('ended', 924),
#  ('creepy', 924),
#  ('concept', 924),
#  ('somewhere', 924),
#  ('vampire', 924),
#  ('spend', 921),
#  ('th', 921),
#  ('future', 918),
#  ('difficult', 918),
#  ('effect', 918),
#  ('fighting', 918),
#  ('street', 918),
#  ('c', 915),
#  ('america', 915),
#  ('accent', 912),
#  ('truth', 906),
#  ('project', 906),
#  ('joe', 903),
#  ('f', 903),
#  ('deal', 903),
#  ('indeed', 903),
#  ('biggest', 900),
#  ('rate', 900),
#  ('paul', 897),
#  ('japanese', 897),
#  ('utterly', 894),
#  ('begins', 894),
#  ('redeeming', 894),
#  ('college', 894),
#  ('york', 891),
#  ('fairly', 891),
#  ('disney', 891),
#  ('crew', 888),
#  ('create', 888),
#  ('cartoon', 888),
#  ('revenge', 888),
#  ('co', 885),
#  ('outside', 885),
#  ('computer', 885),
#  ('interested', 885),
#  ('stage', 885),
#  ('considering', 882),
#  ('speak', 882),
#  ('among', 882),
#  ('towards', 879),
#  ('channel', 879),
#  ('sick', 879),
#  ('talented', 876),
#  ('cause', 876),
#  ('particular', 876),
#  ('van', 876),
#  ('hair', 876),
#  ('bottom', 873),
#  ('reasons', 873),
#  ('mediocre', 870),
#  ('cat', 870),
#  ('telling', 870),
#  ('supporting', 867),
#  ('store', 867),
#  ('hoping', 864),
#  ('waiting', 864),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times

for i, cnt in total_counts.most_common():
    if cnt < 100:
        continue
    pos_neg_ratios[i] += (positive_counts[i] / float(negative_counts[i] + 1))

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0608036428326615
# Pos-to-neg ratio for 'amazing' = 4.033036848792884
# Pos-to-neg ratio for 'terrible' = 0.17752755150934355

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs

for i, ratio in pos_neg_ratios.most_common():
    
    if(ratio > 1):
        pos_neg_ratios[i] = np.log(ratio)    
    else:
        pos_neg_ratios[i] = -np.log(1/(ratio + 0.01))

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902677448642055
# Pos-to-neg ratio for 'amazing' = 1.3945196526689512
# Pos-to-neg ratio for 'terrible' = -1.6738295029833334

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.7899601708972535),
#  ('antwone', 5.575949103146316),
#  ('din', 5.5053315359323625),
#  ('gunga', 5.288267030694535),
#  ('goldsworthy', 5.272999558563747),
#  ('gypo', 5.19295685089021),
#  ('yokai', 5.19295685089021),
#  ('visconti', 5.030437921392435),
#  ('flavia', 5.030437921392435),
#  ('blandings', 4.969813299576001),
#  ('kells', 4.969813299576001),
#  ('brashear', 4.948759890378168),
#  ('gino', 4.927253685157205),
#  ('deathtrap', 4.90527477843843),
#  ('harilal', 4.812184355372417),
#  ('panahi', 4.812184355372417),
#  ('ossessione', 4.762173934797756),
#  ('tsui', 4.736198448394496),
#  ('caruso', 4.736198448394496),
#  ('sabu', 4.709530201312334),
#  ('ahmad', 4.709530201312334),
#  ('khouri', 4.68213122712422),
#  ('dominick', 4.68213122712422),
#  ('aweigh', 4.653960350157523),
#  ('mj', 4.653960350157523),
#  ('mcintire', 4.624972813284271),
#  ('kriemhild', 4.624972813284271),
#  ('paulie', 4.483002552013883),
#  ('iturbi', 3.6826098411003407),
#  ('gundam', 3.6744907166618366),
#  ('giovanna', 3.58351893845611),
#  ('feinstone', 3.58351893845611),
#  ('luzhin', 3.518980417318539),
#  ('philo', 3.4735180432417816),
#  ('lindy', 3.449987545831587),
#  ('clutter', 3.3758795736778655),
#  ('anchors', 3.349904087274605),
#  ('felix', 3.295836866004329),
#  ('korda', 3.2676659890376327),
#  ('capote', 3.2635760037861075),
#  ('callahan', 3.2386784521643803),
#  ('excellently', 3.230239583518516),
#  ('aiello', 3.2088254890146994),
#  ('fido', 3.190476350346503),
#  ('deanna', 3.1780538303479458),
#  ('hayworth', 3.1780538303479458),
#  ('vance', 3.126760535960395),
#  ('kolchak', 3.1135153092103742),
#  ('sammo', 3.1039458581942236),
#  ('laputa', 3.0845277723371223),
#  ('sox', 3.0155349008501706),
#  ('myrtle', 3.002849741322855),
#  ('adele', 3.002849741322855),
#  ('gackt', 3.002849741322855),
#  ('alvin', 3.0007198150650303),
#  ('biko', 2.9763141876968895),
#  ('bernsen', 2.959364629383116),
#  ('gannon', 2.959364629383116),
#  ('mathieu', 2.954910279033736),
#  ('polanski', 2.941144083269588),
#  ('gilliam', 2.9069010598473755),
#  ('matthau', 2.883682769745368),
#  ('harriet', 2.8213788864092133),
#  ('chavez', 2.810329050222628),
#  ('ratso', 2.7963428082478883),
#  ('zu', 2.790288299339182),
#  ('abu', 2.790288299339182),
#  ('sammi', 2.790288299339182),
#  ('warhols', 2.790288299339182),
#  ('ultimatum', 2.785011242238338),
#  ('rosenstrasse', 2.763620052257021),
#  ('victoria', 2.726483902791048),
#  ('delightfully', 2.70805020110221),
#  ('taker', 2.70805020110221),
#  ('corbett', 2.6925460145662448),
#  ('mildred', 2.6897010624340134),
#  ('creasy', 2.6878474937846906),
#  ('mclaglen', 2.68273239311792),
#  ('durbin', 2.6790626642289577),
#  ('vonnegut', 2.6461747973841225),
#  ('braveheart', 2.644536795379884),
#  ('kazan', 2.6280074934286737),
#  ('natali', 2.624668592163159),
#  ('sirk', 2.620081428156253),
#  ('pita', 2.618438042412523),
#  ('gandhi', 2.615934912194404),
#  ('mccoy', 2.5745188084776873),
#  ('cheadle', 2.559014621941722),
#  ('othello', 2.548622464174108),
#  ('novak', 2.536199944175551),
#  ('elsa', 2.533696813957432),
#  ('flawless', 2.5199979695992702),
#  ('jabba', 2.509599262378372),
#  ('christy', 2.507379505640059),
#  ('cal', 2.503954844758695),
#  ('fuller', 2.497978731355353),
#  ('ramones', 2.497978731355353),
#  ('coop', 2.4849066497880004),
#  ('fagin', 2.4595888418037104),
#  ('hanzo', 2.4595888418037104),
#  ('winchester', 2.45315795147342),
#  ('rea', 2.445685936634719),
#  ('haines', 2.445685936634719),
#  ('colman', 2.445685936634719),
#  ('chamberlain', 2.4368974306016398),
#  ('beetle', 2.4336133554004498),
#  ('influential', 2.4069451083182885),
#  ('kalifornia', 2.4069451083182885),
#  ('northam', 2.3838105329166317),
#  ('vertigo', 2.379546134130174),
#  ('carla', 2.3642786619993856),
#  ('stardust', 2.362304327695668),
#  ('sabrina', 2.3513752571634776),
#  ('finely', 2.3513752571634776),
#  ('stevenson', 2.3513752571634776),
#  ('cheung', 2.3513752571634776),
#  ('peters', 2.338303175596125),
#  ('kinnear', 2.3333567516607996),
#  ('tenant', 2.3285605793973065),
#  ('celine', 2.322387720290225),
#  ('superbly', 2.317183892415198),
#  ('enchanting', 2.294863046900135),
#  ('vulnerability', 2.2925347571405443),
#  ('hark', 2.2925347571405443),
#  ('marjorie', 2.2925347571405443),
#  ('darius', 2.2925347571405443),
#  ('raines', 2.2842359543258492),
#  ('pecker', 2.2713325494899412),
#  ('georges', 2.2650471736749807),
#  ('benoit', 2.2617630984737906),
#  ('duryea', 2.2617630984737906),
#  ('devotion', 2.2472349979108808),
#  ('rukh', 2.2364452904895007),
#  ('trier', 2.2317107534073886),
#  ('fairytale', 2.2300144001592104),
#  ('tel', 2.2300144001592104),
#  ('askey', 2.2300144001592104),
#  ('ella', 2.2300144001592104),
#  ('dixon', 2.2090590349832224),
#  ('perfection', 2.20494662343013),
#  ('miyazaki', 2.1972245773362196),
#  ('cheech', 2.1972245773362196),
#  ('astaire', 2.188856327665703),
#  ('malone', 2.1564025828159643),
#  ('edith', 2.1546649629174235),
#  ('clarence', 2.144580843850797),
#  ('mol', 2.1347042203548856),
#  ('scoop', 2.1184436994831053),
#  ('pickford', 2.1184436994831053),
#  ('zorro', 2.105417028083097),
#  ('enthralling', 2.089010992695987),
#  ('mostel', 2.089010992695987),
#  ('henderson', 2.089010992695987),
#  ('dandy', 2.085107279215513),
#  ('voight', 2.082814226158475),
#  ('heartbreaking', 2.0693912058263346),
#  ('captures', 2.0656482195475),
#  ('corbin', 2.0600234558227344),
#  ('lila', 2.0600234558227344),
#  ('wang', 2.043073897508961),
#  ('wonderfully', 2.0395956331326364),
#  ('truman', 2.032921526044943),
#  ('chang', 2.030170492673053),
#  ('booker', 2.030170492673053),
#  ('sunrise', 2.02537432040956),
#  ('hawke', 2.0149030205422647),
#  ('sg', 2.0149030205422647),
#  ('masterson', 2.0149030205422647),
#  ('masterful', 2.0084305060366474),
#  ('powell', 2.0043209112117277),
#  ('sematary', 1.9993988340062996),
#  ('brosnan', 1.9973587108913553),
#  ('expertly', 1.9965538818740682),
#  ('busby', 1.989585212557975),
#  ('holt', 1.989585212557975),
#  ('informer', 1.989585212557975),
#  ('tomei', 1.9828147059907644),
#  ('europa', 1.9740810260220096),
#  ('keeler', 1.9676501356917193),
#  ('connolly', 1.9676501356917193),
#  ('carface', 1.9676501356917193),
#  ('zabriskie', 1.9676501356917193),
#  ('batwoman', 1.9676501356917193),
#  ('greene', 1.9608357992719891),
#  ('lily', 1.9603821816638478),
#  ('cypher', 1.9588135538912212),
#  ('darren', 1.9550845253313545),
#  ('bakshi', 1.9429904389519785),
#  ('pegg', 1.9393954680341194),
#  ('vincenzo', 1.936941479072553),
#  ('leia', 1.9348603128687283),
#  ('crouse', 1.9348603128687283),
#  ('witherspoon', 1.9348603128687283),
#  ('lincoln', 1.9308722716907727),
#  ('carell', 1.9160571859056321),
#  ('parrot', 1.9153734251952317),
#  ('precise', 1.9153734251952317),
#  ('marcus', 1.9095425048844386),
#  ('montana', 1.9065349838204833),
#  ('massey', 1.8918429277850375),
#  ('evans', 1.8918429277850375),
#  ('lemmon', 1.8912890645750882),
#  ('walsh', 1.8897398775882588),
#  ('apartheid', 1.8813716279177422),
#  ('refreshing', 1.8792788472446116),
#  ('breathtaking', 1.87752629098548),
#  ('explores', 1.8772816426662169),
#  ('steele', 1.8772816426662169),
#  ('bourne', 1.8738244222823592),
#  ('scorpion', 1.8523840910444898),
#  ('bittersweet', 1.8430527636156055),
#  ('cedric', 1.8430527636156055),
#  ('ira', 1.8362112317988888),
#  ('deliciously', 1.8362112317988888),
#  ('flynn', 1.8319255109533896),
#  ('chess', 1.8285734423507713),
#  ('celeste', 1.8225311278948086),
#  ('moonstruck', 1.8225311278948086),
#  ('dukakis', 1.8225311278948086),
#  ('dickinson', 1.8225311278948086),
#  ('quintessential', 1.8177349556313156),
#  ('myrna', 1.8177349556313156),
#  ('delightful', 1.8175119653304697),
#  ('homer', 1.8147489874527538),
#  ('affection', 1.807759810574496),
#  ('andrews', 1.8072636557640203),
#  ('soccer', 1.803320291629131),
#  ('lumet', 1.791759469228055),
#  ('kidman', 1.791759469228055),
#  ('ealing', 1.791759469228055),
#  ('han', 1.791759469228055),
#  ('sopranos', 1.7769443834429144),
#  ('nina', 1.7737409637253767),
#  ('beautifully', 1.773166636151439),
#  ('elvira', 1.7691169924782952),
#  ('determination', 1.768769951003356),
#  ('zelah', 1.7650912221458936),
#  ('paula', 1.75539182505718),
#  ('deliverance', 1.75539182505718),
#  ('gripping', 1.7459499331967607),
#  ('underrated', 1.7384781026151184),
#  ('reeve', 1.7366996920450277),
#  ('tierney', 1.7311348474116202),
#  ('ae', 1.7298840655099674),
#  ('hedy', 1.7272209480904839),
#  ('rugged', 1.7272209480904839),
#  ('wai', 1.7272209480904839),
#  ('marisa', 1.7211419020141017),
#  ('stadium', 1.7211419020141017),
#  ('soylent', 1.717651497074333),
#  ('superb', 1.7156449752072436),
#  ('gershwin', 1.7083778602890038),
#  ('technicolor', 1.707202081199992),
#  ('sadness', 1.7012454616872232),
#  ('kline', 1.6993861490970399),
#  ('delight', 1.6985019757414723),
#  ('alienate', 1.6933193964148026),
#  ('rainer', 1.6933193964148026),
#  ('welles', 1.6845139388744574),
#  ('conductor', 1.6711314814394402),
#  ('timeless', 1.6631420914059614),
#  ('macy', 1.6611392868109909),
#  ('kurosawa', 1.6582280766035324),
#  ('dustin', 1.6582280766035324),
#  ('sinatra', 1.6558038329920262),
#  ('grayson', 1.6549002865108577),
#  ('clara', 1.6536091307472378),
#  ('liu', 1.6536091307472378),
#  ('einstein', 1.6536091307472378),
#  ('hartley', 1.6494432470477995),
#  ('touching', 1.6466515087745348),
#  ('unforgettable', 1.6459075922154918),
#  ('eagle', 1.6451559950361796),
#  ('scarlett', 1.6451559950361796),
#  ('layered', 1.6451559950361796),
#  ('favorites', 1.6376087894007967),
#  ('mesmerizing', 1.6349169977350853),
#  ('extraordinary', 1.6326947745983675),
#  ('sullivan', 1.6304913216319328),
#  ('shanghai', 1.62924053973028),
#  ('iran', 1.6266797188686064),
#  ('stewart', 1.6205824769871655),
#  ('conflicted', 1.6199092123013956),
#  ('maturity', 1.6199092123013956),
#  ('gently', 1.6199092123013956),
#  ('showcases', 1.6199092123013956),
#  ('captivated', 1.6184877479540183),
#  ('relaxed', 1.6184877479540183),
#  ('fritz', 1.6184877479540183),
#  ('delirious', 1.6174060820832772),
#  ('johansson', 1.6174060820832772),
#  ('fairbanks', 1.6165553802029644),
#  ('wrenching', 1.6158688027643908),
#  ('heartwarming', 1.6153030318864985),
#  ('brilliantly', 1.611049516328442),
#  ('watson', 1.6000920500158626),
#  ('election', 1.5976034547870976),
#  ('lang', 1.5950491749820008),
#  ('rowlands', 1.5950491749820008),
#  ('palma', 1.5910887737659039),
#  ('blondell', 1.5910887737659039),
#  ('gretchen', 1.5910887737659039),
#  ('crowe', 1.5910887737659039),
#  ('dictator', 1.5910887737659039),
#  ('cloth', 1.5881605139868153),
#  ('understated', 1.587459005715325),
#  ('simmons', 1.5859074150239063),
#  ('friendship', 1.5814640603916943),
#  ('elliott', 1.5730702682632254),
#  ('ritter', 1.5686159179138452),
#  ('benefits', 1.5686159179138452),
#  ('cena', 1.5686159179138452),
#  ('diego', 1.5686159179138452),
#  ('shahid', 1.5686159179138452),
#  ('wonderful', 1.566868174969685),
#  ('conveys', 1.5652318199296047),
#  ('magnificent', 1.5612358106162227),
#  ('jackie', 1.5603171150991502),
#  ('finest', 1.5599578551707307),
#  ('nathan', 1.5569198781506541),
#  ('buffalo', 1.5569198781506541),
#  ('loy', 1.5564453822935902),
#  ('climate', 1.5553706911638245),
#  ('metropolis', 1.5553706911638245),
#  ('maguire', 1.5553706911638245),
#  ('scrooge', 1.550597412411167),
#  ('tremendous', 1.547880019434667),
#  ('spock', 1.5375253308438142),
#  ('heartfelt', 1.536867219599265),
#  ('odyssey', 1.5358260950908544),
#  ('pickup', 1.5339303599259553),
#  ('irving', 1.5339303599259553),
#  ('sondra', 1.5276078941864681),
#  ('freedom', 1.5243826629370196),
#  ('pleasantly', 1.5188924825614147),
#  ('mann', 1.5188924825614147),
#  ('riff', 1.5173226235262947),
#  ('hyde', 1.5168164225537037),
#  ('sidewalk', 1.5147726858930222),
#  ('absorbing', 1.5147726858930222),
#  ('longing', 1.5147726858930222),
#  ('cunningham', 1.5147726858930222),
#  ('sidney', 1.5143338969434632),
#  ('delicate', 1.5130460667590344),
#  ('astonishing', 1.5117994428701844),
#  ('andre', 1.5117994428701844),
#  ('stack', 1.5117994428701844),
#  ('terrific', 1.5111445639993666),
#  ('fantastic', 1.509451689942051),
#  ('nancy', 1.5040773967762742),
#  ('kitty', 1.5040773967762742),
#  ('jedi', 1.5040773967762742),
#  ('soprano', 1.5040773967762742),
#  ('jose', 1.5040773967762742),
#  ('ewoks', 1.5040773967762742),
#  ('daria', 1.5040773967762742),
#  ('floriane', 1.5040773967762742),
#  ('noir', 1.50262073227981),
#  ('outstanding', 1.499701022176475),
#  ('marie', 1.4968571488027869),
#  ('marvelous', 1.4964727973910548),
#  ('hadley', 1.4932664806720584),
#  ('stargate', 1.4894785973551214),
#  ('ruth', 1.4890395194117334),
#  ('sassy', 1.4872702784598928),
#  ('fontaine', 1.4872702784598928),
#  ('enhances', 1.4863778196768733),
#  ('hare', 1.4863778196768733),
#  ('gardens', 1.4863778196768733),
#  ('detract', 1.4842747694800944),
#  ('iranian', 1.4799798451972137),
#  ('layers', 1.4766784225881595),
#  ('macarthur', 1.4733057381095203),
#  ('rousing', 1.4733057381095203),
#  ('entertains', 1.4733057381095203),
#  ('sorrow', 1.4733057381095203),
#  ('gen', 1.4733057381095203),
#  ('berenger', 1.4733057381095203),
#  ('demille', 1.4712875739532831),
#  ('jacques', 1.4712875739532831),
#  ('gielgud', 1.4712875739532831),
#  ('excellent', 1.4664691168591149),
#  ('stark', 1.4645465580196388),
#  ('definitive', 1.464072062162575),
#  ('taut', 1.463255402256019),
#  ('affecting', 1.463255402256019),
#  ('melancholy', 1.463255402256019),
#  ('espionage', 1.463255402256019),
#  ('sheridan', 1.463255402256019),
#  ('melbourne', 1.463255402256019),
#  ('stanwyck', 1.4629501053524112),
#  ('widmark', 1.4575573811413813),
#  ('splendid', 1.455287232606842),
#  ('dismiss', 1.455287232606842),
#  ('denis', 1.4527841023887236),
#  ('tender', 1.4448885253859434),
#  ('exceptional', 1.4434527749598391),
#  ('vienna', 1.4415570397949402),
#  ('chan', 1.4399154525589883),
#  ('gentle', 1.4372144515471477),
#  ('ruby', 1.4350845252893227),
#  ('meek', 1.4350845252893227),
#  ('travolta', 1.4350845252893227),
#  ('cloak', 1.4350845252893227),
#  ('maintains', 1.4299694246225523),
#  ('shin', 1.4299694246225523),
#  ('pathos', 1.425825199876526),
#  ('poignant', 1.4240346891027378),
#  ('dickens', 1.4220124437219699),
#  ('cerebral', 1.419520008748211),
#  ('restrained', 1.419520008748211),
#  ('captivating', 1.4144652380865868),
#  ('sentinel', 1.4131056185705473),
#  ('fisher', 1.4122698475231514),
#  ('davies', 1.4122698475231514),
#  ('elegant', 1.4087672169719492),
#  ('rizzo', 1.4087672169719492),
#  ('prophet', 1.4087672169719492),
#  ('chilling', 1.4060969884160703),
#  ('everett', 1.4060969884160703),
#  ('favourites', 1.4039939382192914),
#  ('gem', 1.402517196626778),
#  ('neglected', 1.4022947024663317),
#  ('rewarding', 1.4008931605410433),
#  ('pixar', 1.3987168811184478),
#  ('gerard', 1.3953441966398086),
#  ('amazing', 1.3945196526689512),
#  ('darker', 1.3934118288887545),
#  ('april', 1.3821875791672373),
#  ('uplifting', 1.3811792604531203),
#  ('standout', 1.379514674134512),
#  ('stunningly', 1.379514674134512),
#  ('amrita', 1.379514674134512),
#  ('juliette', 1.378914253822268),
#  ('vanilla', 1.378914253822268),
#  ('fleet', 1.3781971508872712),
#  ('landmark', 1.3773256911371303),
#  ('duchovny', 1.3773256911371303),
#  ('irresistible', 1.3748656652962679),
#  ('elisha', 1.3748656652962679),
#  ('blake', 1.37125648375535),
#  ('cushing', 1.3627638637096964),
#  ('delicious', 1.3588953869317761),
#  ('thelma', 1.3564413979702095),
#  ('overlooked', 1.3541372494853594),
#  ('kelly', 1.3536931997444925),
#  ('enchanted', 1.3535045382968998),
#  ('reiser', 1.3535045382968998),
#  ('gentleman', 1.3520611894776484),
#  ('ralph', 1.349926716949016),
#  ('marc', 1.349926716949016),
#  ('dangerously', 1.349926716949016),
#  ('noam', 1.3454723665996355),
#  ('malden', 1.3454723665996355),
#  ('midler', 1.3454723665996355),
#  ('errol', 1.3415584672784993),
#  ('engrossing', 1.3415584672784993),
#  ('overwhelmed', 1.3397743454849977),
#  ('supremacy', 1.3397743454849977),
#  ('swim', 1.3370233121131079),
#  ('bud', 1.3370233121131079),
#  ('cole', 1.3362839405452291),
#  ('bette', 1.3360856655371443),
#  ('hoffman', 1.331873970147904),
#  ('dalton', 1.3315438463484823),
#  ('preminger', 1.330413902725434),
#  ('richardson', 1.3286287192700814),
#  ('randall', 1.32818673031261),
#  ('sho', 1.32818673031261),
#  ('neill', 1.3263962195388217),
#  ('shines', 1.3260021308637706),
#  ('orphan', 1.3217558399823195),
#  ('tess', 1.3217558399823195),
#  ('meadows', 1.3217558399823195),
#  ('collaboration', 1.3137236682850553),
#  ('lanza', 1.3137236682850553),
#  ('willy', 1.3137236682850553),
#  ('lars', 1.3137236682850553),
#  ('drummer', 1.3137236682850553),
#  ('winters', 1.3127602770737414),
#  ('notch', 1.3106710075578265),
#  ('sailor', 1.3099213823353166),
#  ('pfeiffer', 1.3099213823353166),
#  ('powerful', 1.3049914138340664),
#  ('vivid', 1.3044643428722584),
#  ('denied', 1.3034067013141228),
#  ('lovingly', 1.3034067013141228),
#  ('flea', 1.3034067013141228),
#  ('pets', 1.3034067013141228),
#  ('levant', 1.3034067013141228),
#  ('stubborn', 1.3034067013141228),
#  ('bolivia', 1.3034067013141228),
#  ('pitt', 1.3022112439093492),
#  ('scariest', 1.3015531326648),
#  ('loneliness', 1.3011365527795837),
#  ('giallo', 1.3004784415350346),
#  ('remarkable', 1.2983689072841658),
#  ('riveting', 1.2964380319980295),
#  ('orleans', 1.295971722826605),
#  ('divine', 1.294356865794205),
#  ('frontier', 1.294356865794205),
#  ('psychiatrist', 1.2935126276689244),
#  ('edmund', 1.292768303109067),
#  ('colony', 1.292768303109067),
#  ('cleverly', 1.2918035176989682),
#  ('portrait', 1.2915159547926012),
#  ('gritty', 1.2913778046231477),
#  ('innocence', 1.2892326482767593),
#  ('garbo', 1.2883688239495823),
#  ('ensemble', 1.286075244962483),
#  ('holly', 1.2809338454620642),
#  ('strengths', 1.2809338454620642),
#  ('missions', 1.2809338454620642),
#  ('richly', 1.2809338454620642),
#  ('sleeper', 1.2809338454620642),
#  ('fanning', 1.2809338454620642),
#  ('panic', 1.2787384548986287),
#  ('september', 1.2781978656431896),
#  ('burns', 1.2766875545806133),
#  ('excellence', 1.2755429968271879),
#  ('thailand', 1.2755429968271879),
#  ('candle', 1.2755429968271879),
#  ('philip', 1.2714551015075206),
#  ('barbara', 1.270462545594769),
#  ('carol', 1.2698840092754793),
#  ('stunning', 1.26967669093743),
#  ('favorite', 1.2693586852184033),
#  ('alexandre', 1.2692378056988731),
#  ('paxton', 1.2672350011039024),
#  ('edges', 1.262915339959386),
#  ('rural', 1.2625001437732262),
#  ('appreciated', 1.2615157596049626),
#  ('rookie', 1.259880436264232),
#  ('energetic', 1.259880436264232),
#  ('vividly', 1.259880436264232),
#  ('accessible', 1.259880436264232),
#  ('alison', 1.257676983297797),
#  ('brooklyn', 1.2568362938830038),
#  ('builds', 1.2565153181139184),
#  ('favourite', 1.2501621867953105),
#  ('sissy', 1.2501621867953105),
#  ('pierce', 1.2501621867953105),
#  ('neatly', 1.2494351784026934),
#  ('cultures', 1.2488944917174476),
#  ('lavish', 1.2488944917174476),
#  ('vega', 1.2488944917174476),
#  ('perfect', 1.2486116401364886),
#  ('garfield', 1.2481440226390734),
#  ('michaels', 1.247032293786383),
#  ('izzard', 1.247032293786383),
#  ('unfolds', 1.2445662012911896),
#  ('journey', 1.2435194096118067),
#  ('rifle', 1.241713132308783),
#  ('von', 1.2411753533229801),
#  ('bond', 1.2408393882601862),
#  ('coup', 1.2402628057311365),
#  ('devastating', 1.2383742310432684),
#  ('bacall', 1.2362336665441573),
#  ('maureen', 1.2358134101815947),
#  ('sterling', 1.2358134101815947),
#  ('effortlessly', 1.2321436812926323),
#  ('lin', 1.2321436812926323),
#  ('reese', 1.2321436812926323),
#  ('brilliant', 1.2312184691988761),
#  ('bsg', 1.2292324710851739),
#  ('phenomenal', 1.2253639943072534),
#  ('cuban', 1.2253639943072534),
#  ('posey', 1.2249060139924017),
#  ('recommended', 1.222365491310997),
#  ('anton', 1.221214610760442),
#  ('hugo', 1.2199731456723772),
#  ('rita', 1.2184134884807303),
#  ('sublime', 1.2163953243244932),
#  ('berkeley', 1.2163953243244932),
#  ('daniel', 1.2143482407027684),
#  ('reflects', 1.214125175789954),
#  ('crafted', 1.2134925646665318),
#  ('troubled', 1.2119409739751128),
#  ('compromise', 1.2119409739751128),
#  ('dangers', 1.2119409739751128),
#  ('compositions', 1.2119409739751128),
#  ('consequences', 1.209837923778334),
#  ('paths', 1.209837923778334),
#  ('october', 1.209837923778334),
#  ('masterfully', 1.2086131838824383),
#  ('bravo', 1.2086131838824383),
#  ('reign', 1.2078115806331018),
#  ('viewings', 1.2072461296709052),
#  ('prince', 1.2034919194885851),
#  ('perfectly', 1.2017077976950838),
#  ('beckinsale', 1.201266442728193),
#  ('collapse', 1.200394982978052),
#  ('freed', 1.200394982978052),
#  ('kilmer', 1.200394982978052),
#  ('alexander', 1.1992558144477972),
#  ('kyle', 1.1979847624813134),
#  ('championship', 1.1970523614813622),
#  ('ustinov', 1.1970523614813622),
#  ('boxing', 1.195986452693286),
#  ('haunting', 1.1939224684724346),
#  ('solo', 1.1939224684724346),
#  ('cinderella', 1.1922478937021024),
#  ('whimsical', 1.1909856087991249),
#  ('lubitsch', 1.1909856087991249),
#  ('ladder', 1.1904198379212325),
#  ('karl', 1.1856236656577395),
#  ('curtis', 1.184789984909162),
#  ('voyager', 1.1831696766961728),
#  ('brent', 1.1831696766961728),
#  ('biopic', 1.1831696766961728),
#  ('emotions', 1.182577668785444),
#  ('subtle', 1.1799070310613564),
#  ('marion', 1.177393166521224),
#  ('clan', 1.1770839041096048),
#  ('lends', 1.1765738301378217),
#  ('aftermath', 1.1765738301378217),
#  ('unusually', 1.1765738301378217),
#  ('impeccable', 1.1755733298042381),
#  ('duff', 1.1755733298042381),
#  ('depicts', 1.1738357099056973),
#  ('paramount', 1.1688165473413583),
#  ('daughters', 1.1686798512848267),
#  ('marrying', 1.1676051601550612),
#  ('hale', 1.1676051601550612),
#  ('coal', 1.1676051601550612),
#  ('throne', 1.1676051601550612),
#  ('interplay', 1.1676051601550612),
#  ('pertwee', 1.1676051601550612),
#  ('mice', 1.1660535694636422),
#  ('rare', 1.1629530054335593),
#  ('courage', 1.1625610132683832),
#  ('exquisite', 1.1617911902896414),
#  ('dominate', 1.1611326456494435),
#  ('upbeat', 1.1611326456494435),
#  ('avoids', 1.1611326456494435),
#  ('dentist', 1.1608545975453306),
#  ('loved', 1.1583173701898661),
#  ('loretta', 1.1580357091389104),
#  ('globe', 1.1580357091389104),
#  ('vibrant', 1.1580357091389104),
#  ('draws', 1.1557707025080584),
#  ('aime', 1.1557707025080584),
#  ('nominated', 1.1533371883573562),
#  ('manners', 1.1512560221535317),
#  ('loyalty', 1.1490431422950016),
#  ('herbert', 1.1474024528375417),
#  ('everyday', 1.1470088295299599),
#  ('tony', 1.1450123642728738),
#  ('cried', 1.144597401909933),
#  ('highly', 1.1444218246994038),
#  ('damon', 1.1444218246994038),
#  ('irene', 1.144074662744867),
#  ('lola', 1.144074662744867),
#  ('caron', 1.144074662744867),
#  ('fay', 1.1430640512389434),
#  ('realities', 1.1411719030869056),
#  ('contrast', 1.140660524911609),
#  ('orson', 1.1405764877671418),
#  ('corruption', 1.1388861878060497),
#  ('concentrates', 1.1378330018213911),
#  ('entertainer', 1.1378330018213911),
#  ('lamarr', 1.1378330018213911),
#  ('jessie', 1.1378330018213911),
#  ('azaria', 1.1378330018213911),
#  ('lung', 1.1378330018213911),
#  ('fabulous', 1.1363526166509568),
#  ('ned', 1.1355168456035607),
#  ('dedication', 1.13370360847938),
#  ('mastroianni', 1.13370360847938),
#  ('granger', 1.13370360847938),
#  ('simba', 1.13370360847938),
#  ('newman', 1.132513840343791),
#  ('emma', 1.1318379362964301),
#  ('sensual', 1.13036098698269),
#  ('smooth', 1.1300284849014886),
#  ('sensitive', 1.128244086274481),
#  ('simplicity', 1.1280261738744028),
#  ('wartime', 1.127599825541362),
#  ('criticized', 1.127599825541362),
#  ('portuguese', 1.127599825541362),
#  ('ernie', 1.127599825541362),
#  ('dramas', 1.127322394550541),
#  ('shelley', 1.126783165634806),
#  ('playwright', 1.125280535750271),
#  ('arkin', 1.1233049012584813),
#  ('owl', 1.1233049012584813),
#  ('isolation', 1.1216018068928084),
#  ('packs', 1.1216018068928084),
#  ('dazzling', 1.1201184938890731),
#  ('contribution', 1.1201184938890731),
#  ('inspiring', 1.1184149159642893),
#  ('beatles', 1.116630794170788),
#  ('vader', 1.116630794170788),
#  ('wwe', 1.11570672202741),
#  ('deniro', 1.1148728095398899),
#  ('warmth', 1.1141164752040749),
#  ('tends', 1.1141164752040749),
#  ('june', 1.1134273744532504),
#  ('thoughtful', 1.1122179407238884),
#  ('stellar', 1.1116843702354624),
#  ('helps', 1.1097441290369539),
#  ('today', 1.1071960323595011),
#  ('jimmy', 1.1034784783192826),
#  ('awesome', 1.0986122886681098),
#  ('rival', 1.0986122886681098),
#  ('depression', 1.0986122886681098),
#  ('shy', 1.0986122886681098),
#  ('carrie', 1.0986122886681098),
#  ('blend', 1.0986122886681098),
#  ('hank', 1.0986122886681098),
#  ('diana', 1.0986122886681098),
#  ('adorable', 1.0986122886681098),
#  ('affect', 1.0986122886681098),
#  ('intimate', 1.0986122886681098),
#  ('poem', 1.0986122886681098),
#  ('renaissance', 1.0986122886681098),
#  ('prominent', 1.0986122886681098),
#  ('rounded', 1.0986122886681098),
#  ('mitch', 1.0986122886681098),
#  ('fishburne', 1.0986122886681098),
#  ('macabre', 1.0986122886681098),
#  ('vintage', 1.0986122886681098),
#  ('psyche', 1.0986122886681098),
#  ('kirsten', 1.0986122886681098),
#  ('influences', 1.0986122886681098),
#  ('rivalry', 1.0986122886681098),
#  ('symbols', 1.0986122886681098),
#  ('damsel', 1.0986122886681098),
#  ('keeper', 1.0986122886681098),
#  ('hustler', 1.0986122886681098),
#  ('heavenly', 1.0986122886681098),
#  ('mcadams', 1.0986122886681098),
#  ('tragic', 1.0947881922297062),
#  ('intense', 1.0947438118901893),
#  ('unique', 1.092316360211295),
#  ('achievement', 1.0879169995513618),
#  ('provides', 1.0872269664429843),
#  ('glorious', 1.0858732628906798),
#  ('dub', 1.084818966535774),
#  ('unexpected', 1.0826968333622102),
#  ('bettie', 1.0823517677963295),
#  ('esther', 1.0812205459562405),
#  ('wilder', 1.0802631499999131),
#  ('happiness', 1.0772591641975406),
#  ('enhanced', 1.0766333819493346),
#  ('collette', 1.0750817912579156),
#  ('cliffhanger', 1.0750817912579156),
#  ('fassbinder', 1.0750817912579156),
#  ('wider', 1.0732944806838198),
#  ('ideal', 1.072969858054772),
#  ('lena', 1.0719440415859482),
#  ('nuanced', 1.0712133144799951),
#  ('je', 1.0712133144799951),
#  ('terrifying', 1.070703500551033),
#  ('surround', 1.0687593255184284),
#  ('polar', 1.0687593255184284),
#  ('fears', 1.0671960924347308),
#  ('glenda', 1.0658224658451187),
#  ('lighthearted', 1.0658224658451187),
#  ('muni', 1.0658224658451187),
#  ('palance', 1.065275868400518),
#  ('laurence', 1.0635209688568397),
#  ('volumes', 1.0622446444972349),
#  ('bonds', 1.0622446444972349),
#  ('mcgavin', 1.0622446444972349),
#  ('oldest', 1.0615710169877606),
#  ('muppets', 1.0615710169877606),
#  ('davis', 1.0614332854263557),
#  ('sandra', 1.05833838953017),
#  ('hong', 1.0572270725052555),
#  ('startling', 1.0569395922675415),
#  ('gable', 1.0569395922675415),
#  ('bloom', 1.0569395922675415),
#  ('subtly', 1.0569395922675415),
#  ('restored', 1.0548096660097168),
#  ('beauty', 1.0543394649901214),
#  ('seasons', 1.0541605260972757),
#  ('definite', 1.0536609008058433),
#  ('waitress', 1.0528027526368153),
#  ('der', 1.0528027526368153),
#  ('carries', 1.0502157478062595),
#  ('difficulties', 1.0481814350412177),
#  ('kansas', 1.0481814350412177),
#  ('fascinating', 1.04801127537432),
#  ('goodman', 1.0473189942805592),
#  ('artistry', 1.0473189942805592),
#  ('touched', 1.0445450673978338),
#  ('satisfying', 1.0438873889788631),
#  ('reunite', 1.043042437513299),
#  ('bonanza', 1.043042437513299),
#  ('vivian', 1.043042437513299),
#  ('rhythm', 1.0425228220170661),
#  ('robinson', 1.0422593521169778),
#  ('bands', 1.0422593521169778),
#  ('authorities', 1.039188868197309),
#  ('thrilled', 1.039188868197309),
#  ('boyer', 1.039188868197309),
#  ('aunt', 1.037987666851675),
#  ('engineer', 1.037987666851675),
#  ('sergio', 1.037987666851675),
#  ('enterprise', 1.0356984632575403),
#  ('nominations', 1.0354333870465782),
#  ('creates', 1.0344191310290498),
#  ('walter', 1.033692742568794),
#  ('brennan', 1.0319209141694374),
#  ('groove', 1.0319209141694374),
#  ('fragile', 1.031171007872577),
#  ('nightclub', 1.031171007872577),
#  ('miranda', 1.031171007872577),
#  ('spectacular', 1.0299837822790134),
#  ('greatest', 1.0282845465260535),
#  ('gillian', 1.0271533246859648),
#  ('diverse', 1.0262916270884836),
#  ('sang', 1.0262916270884836),
#  ('gage', 1.0245043165143877),
#  ('harlem', 1.0245043165143877),
#  ('sailors', 1.0245043165143877),
#  ('musicals', 1.02395075989909),
#  ('portrayal', 1.0239315241359586),
#  ('comparisons', 1.0231047361599646),
#  ('ann', 1.0214765597858824),
#  ('sweden', 1.0206507471983979),
#  ('bosses', 1.0206507471983979),
#  ('beckham', 1.0206507471983979),
#  ('mature', 1.0197183461984467),
#  ('passionate', 1.0196238773494795),
#  ('triumph', 1.0185695809945732),
#  ('margaret', 1.0185695809945732),
#  ('deeply', 1.0172666492141573),
#  ('evokes', 1.0140549006400466),
#  ('spade', 1.0140549006400466),
#  ('galaxy', 1.013454480327803),
#  ('limitations', 1.013454480327803),
#  ('wonderland', 1.013454480327803),
#  ('vulnerable', 1.0128454669106846),
#  ('incredible', 1.010592542126464),
#  ('navy', 1.0102013313240568),
#  ('lucas', 1.0076405104623831),
#  ('seymour', 1.0076405104623831),
#  ('pierre', 1.0076405104623831),
#  ('joey', 1.0071780827084778),
#  ('stepmother', 1.0062389685370945),
#  ('notices', 1.0062389685370945),
#  ('eugene', 1.004793533450455),
#  ('ingenious', 1.0033021088637848),
#  ('cher', 1.0033021088637848),
#  ('vengeance', 1.001985452979038),
#  ('balance', 1.001762462678192),
#  ('immigrant', 1.0009738191041937),
#  ('dynamics', 1.0009738191041937),
#  ('widow', 0.9997664540314771),
#  ('carrey', 0.9995213860238787),
#  ('guilt', 0.9980710594462322),
#  ('glover', 0.9980710594462322),
#  ('brazil', 0.9979687628884223),
#  ('recognition', 0.9978075895461441),
#  ('eleven', 0.997516171796741),
#  ('conrad', 0.997516171796741),
#  ('harry', 0.9971167993766558),
#  ('representative', 0.9968295943581673),
#  ('liberties', 0.9968295943581673),
#  ('profoundly', 0.9968295943581673),
#  ('expresses', 0.9968295943581673),
#  ('optimism', 0.9968295943581673),
#  ('grady', 0.9968295943581673),
#  ('awe', 0.9959581346080264),
#  ('warm', 0.9956643194156672),
#  ('essence', 0.9952339342142745),
#  ('provocative', 0.9950716097272694),
#  ('ages', 0.9943512783437003),
#  ('sons', 0.9941696253005123),
#  ('sweet', 0.993971456380677),
#  ('du', 0.9932517730102834),
#  ('bauer', 0.9932517730102834),
#  ('rupert', 0.9932517730102834),
#  ('inventive', 0.9918443132424036),
#  ('pirate', 0.9909816244757442),
#  ('sport', 0.9907233266569248),
#  ('oscar', 0.9900721200929037),
#  ('learns', 0.9896220049597046),
#  ('eerie', 0.9884091485344955),
#  ('integrity', 0.9882642314992444),
#  ('holmes', 0.9873866535578852),
#  ('pokemon', 0.9873866535578852),
#  ('convincingly', 0.9873866535578852),
#  ('destiny', 0.9866943724641243),
#  ('unusual', 0.9857577992128753),
#  ('shaolin', 0.9852836033611064),
#  ('apprentice', 0.9852836033611064),
#  ('palette', 0.9852836033611064),
#  ('subtleties', 0.9852836033611064),
#  ('woven', 0.9852836033611064),
#  ('lyrical', 0.9852836033611064),
#  ('smoothly', 0.9852836033611064),
#  ('wits', 0.9852836033611064),
#  ('allison', 0.9852836033611064),
#  ('grounded', 0.9852836033611064),
#  ('supporters', 0.9852836033611064),
#  ('dahl', 0.9852836033611064),
#  ('traditions', 0.9842019374903656),
#  ('achievements', 0.9842019374903656),
#  ('tide', 0.9842019374903656),
#  ('ricky', 0.9835429588833224),
#  ('complex', 0.9833332786449167),
#  ('relax', 0.982780473142988),
#  ('lonely', 0.9816406120826056),
#  ('grim', 0.9816406120826056),
#  ('solid', 0.9802222727199496),
#  ('vhs', 0.9797510857913808),
#  ('thrillers', 0.978811088855489),
#  ('ginger', 0.977984300879495),
#  ('facing', 0.9776596782504472),
#  ('poetic', 0.9776596782504472),
#  ('rosemary', 0.9767224710590727),
#  ('judd', 0.9760099665757773),
#  ('july', 0.974998332700933),
#  ('detroit', 0.974998332700933),
#  ('debut', 0.9743832887059006),
#  ('beautiful', 0.9743803311804031),
#  ('emmy', 0.9734491457141037),
#  ('unravel', 0.9734491457141037),
#  ('manipulated', 0.9734491457141037),
#  ('geoffrey', 0.9734491457141037),
#  ('willis', 0.9725715677727447),
#  ('cox', 0.9716125979068023),
#  ('compassion', 0.971457113182863),
#  ('nolte', 0.9699949108460161),
#  ('comfortable', 0.9697794168251412),
#  ('hooked', 0.9688006771461191),
#  ('stanley', 0.9681594002706745),
#  ('laurie', 0.9679921062510455),
#  ('jules', 0.9679921062510455),
#  ('tears', 0.967210822301412),
#  ('mistress', 0.9670359308793903),
#  ('rose', 0.9664943238407341),
#  ('reflected', 0.965080896043587),
#  ('martino', 0.965080896043587),
#  ('keen', 0.9624801143435296),
#  ('mirrors', 0.9624801143435296),
#  ('winning', 0.9616146880671009),
#  ('feelings', 0.9615904911038186),
#  ('fulfilling', 0.9604619501872925),
#  ('prolific', 0.9604619501872925),
#  ('unnerving', 0.9604619501872925),
#  ('elmer', 0.9604619501872925),
#  ('quirks', 0.9604619501872925),
#  ('snowy', 0.9604619501872925),
#  ('peterson', 0.9604619501872925),
#  ('tolkien', 0.9604619501872925),
#  ('arranged', 0.958850346292951),
#  ('paris', 0.9587019673328152),
#  ('raymond', 0.9575336904082041),
#  ('mgm', 0.956437799887567),
#  ('nomination', 0.954572918445172),
#  ('heart', 0.9541914962443188),
#  ('excels', 0.9534302788236119),
#  ('gena', 0.9534302788236119),
#  ('bronte', 0.9534302788236119),
#  ('perry', 0.9525196701706138),
#  ('mysteries', 0.9520088144762343),
#  ('hal', 0.9520088144762343),
#  ('hara', 0.9501922835498364),
#  ('spinal', 0.9501922835498364),
#  ('blunt', 0.9486721413771949),
#  ('casablanca', 0.9483300856187717),
#  ('lovable', 0.9472126422127413),
#  ('danny', 0.9468654561522459),
#  ('themes', 0.9468062758001056),
#  ('masterpiece', 0.9454338986597907),
#  ('minnelli', 0.9444616088408515),
#  ('anime', 0.9436361857646839),
#  ('attitudes', 0.9422662182774157),
#  ('joy', 0.941082085516199),
#  ('leo', 0.9403882834532156),
#  ('informs', 0.9395475940384223),
#  ('louis', 0.9391845517400076),
#  ('lifestyle', 0.9387635877262136),
#  ('urban', 0.9360933591703348),
#  ('gradually', 0.9360933591703348),
#  ('courtroom', 0.9335325383086612),
#  ('italy', 0.9315582040049435),
#  ('kennedy', 0.9315582040049435),
#  ('youthful', 0.9315582040049435),
#  ('natured', 0.9315582040049435),
#  ('painter', 0.9315582040049435),
#  ('allows', 0.9311333049120839),
#  ('charming', 0.9301936370431465),
#  ('guinness', 0.9299895762323169),
#  ('subsequent', 0.9297914190930577),
#  ('doubts', 0.9276544905244701),
#  ('unpredictable', 0.9276544905244701),
#  ('impact', 0.9244081663941217),
#  ('spy', 0.9242589015233319),
#  ('winter', 0.9230475143370348),
#  ('meyers', 0.9227216222044455),
#  ('demeanor', 0.9216815805090315),
#  ('screened', 0.9216815805090315),
#  ('deepest', 0.9216815805090315),
#  ('rivals', 0.9216815805090315),
#  ('marvin', 0.9216815805090315),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('saif', -4.605170185988092),
#  ('delia', -4.605170185988092),
#  ('sarne', -4.605170185988092),
#  ('gram', -4.605170185988092),
#  ('kornbluth', -4.605170185988092),
#  ('kareena', -4.605170185988092),
#  ('hobgoblins', -4.605170185988092),
#  ('tashan', -4.605170185988092),
#  ('slater', -4.605170185988092),
#  ('boll', -4.075910860533263),
#  ('uwe', -3.918623689459498),
#  ('thunderbirds', -3.6380210368804455),
#  ('beowulf', -3.627799947148156),
#  ('dahmer', -3.549117511738778),
#  ('wayans', -3.5109826833003375),
#  ('ajay', -3.469687361511654),
#  ('grendel', -3.469687361511654),
#  ('awfulness', -3.321823794120643),
#  ('seagal', -3.317089559455733),
#  ('steaming', -3.3026457079336597),
#  ('welch', -3.282802912174433),
#  ('deathstalker', -3.240962612271044),
#  ('gamera', -3.0759758046040435),
#  ('dreck', -3.0303677702167473),
#  ('unwatchable', -3.0218775536583133),
#  ('stinker', -2.982264056503124),
#  ('segal', -2.8796601023012367),
#  ('semblance', -2.8604307949131633),
#  ('mst', -2.7721219051457986),
#  ('incoherent', -2.7598779690460433)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = total_counts.keys()

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros(shape=(1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'bromwell': 0,
#  'high': 1,
#  'is': 2,
#  'a': 3,
#  'cartoon': 4,
#  'comedy': 5,
#  '.': 6,
#  'it': 7,
#  'ran': 8,
#  'at': 9,
#  'the': 10,
#  'same': 11,
#  'time': 12,
#  'as': 13,
#  'some': 14,
#  'other': 15,
#  'programs': 16,
#  'about': 17,
#  'school': 18,
#  'life': 19,
#  'such': 20,
#  'teachers': 21,
#  'my': 22,
#  'years': 23,
#  'in': 24,
#  'teaching': 25,
#  'profession': 26,
#  'lead': 27,
#  'me': 28,
#  'to': 29,
#  'believe': 30,
#  'that': 31,
#  's': 32,
#  'satire': 33,
#  'much': 34,
#  'closer': 35,
#  'reality': 36,
#  'than': 37,
#  'scramble': 38,
#  'survive': 39,
#  'financially': 40,
#  'insightful': 41,
#  'students': 42,
#  'who': 43,
#  'can': 44,
#  'see': 45,
#  'right': 46,
#  'through': 47,
#  'their': 48,
#  'pathetic': 49,
#  'pomp': 50,
#  'pettiness': 51,
#  'of': 52,
#  'whole': 53,
#  'situation': 54,
#  'all': 55,
#  'remind': 56,
#  'schools': 57,
#  'i': 58,
#  'knew': 59,
#  'and': 60,
#  'when': 61,
#  'saw': 62,
#  'episode': 63,
#  'which': 64,
#  'student': 65,
#  'repeatedly': 66,
#  'tried': 67,
#  'burn': 68,
#  'down': 69,
#  'immediately': 70,
#  'recalled': 71,
#  'classic': 72,
#  'line': 73,
#  'inspector': 74,
#  'm': 75,
#  'here': 76,
#  'sack': 77,
#  'one': 78,
#  'your': 79,
#  'welcome': 80,
#  'expect': 81,
#  'many': 82,
#  'adults': 83,
#  'age': 84,
#  'think': 85,
#  'far': 86,
#  'fetched': 87,
#  'what': 88,
#  'pity': 89,
#  'isn': 90,
#  't': 91,
#  'story': 92,
#  'man': 93,
#  'has': 94,
#  'unnatural': 95,
#  'feelings': 96,
#  'for': 97,
#  'pig': 98,
#  'starts': 99,
#  'out': 100,
#  'with': 101,
#  'opening': 102,
#  'scene': 103,
#  'terrific': 104,
#  'example': 105,
#  'absurd': 106,
#  'formal': 107,
#  'orchestra': 108,
#  'audience': 109,
#  'turned': 110,
#  'into': 111,
#  'an': 112,
#  'insane': 113,
#  'violent': 114,
#  'mob': 115,
#  'by': 116,
#  'crazy': 117,
#  'chantings': 118,
#  'singers': 119,
#  'unfortunately': 120,
#  'stays': 121,
#  'no': 122,
#  'general': 123,
#  'narrative': 124,
#  'eventually': 125,
#  'making': 126,
#  'just': 127,
#  'too': 128,
#  'off': 129,
#  'putting': 130,
#  'even': 131,
#  'those': 132,
#  'from': 133,
#  'era': 134,
#  'should': 135,
#  'be': 136,
#  'cryptic': 137,
#  'dialogue': 138,
#  'would': 139,
#  'make': 140,
#  'shakespeare': 141,
#  'seem': 142,
#  'easy': 143,
#  'third': 144,
#  'grader': 145,
#  'on': 146,
#  'technical': 147,
#  'level': 148,
#  'better': 149,
#  'you': 150,
#  'might': 151,
#  'good': 152,
#  'cinematography': 153,
#  'future': 154,
#  'great': 155,
#  'vilmos': 156,
#  'zsigmond': 157,
#  'stars': 158,
#  'sally': 159,
#  'kirkland': 160,
#  'frederic': 161,
#  'forrest': 162,
#  'seen': 163,
#  'briefly': 164,
#  'homelessness': 165,
#  'or': 166,
#  'houselessness': 167,
#  'george': 168,
#  'carlin': 169,
#  'stated': 170,
#  'been': 171,
#  'issue': 172,
#  'but': 173,
#  'never': 174,
#  'plan': 175,
#  'help': 176,
#  'street': 177,
#  'were': 178,
#  'once': 179,
#  'considered': 180,
#  'human': 181,
#  'did': 182,
#  'everything': 183,
#  'going': 184,
#  'work': 185,
#  'vote': 186,
#  'matter': 187,
#  'most': 188,
#  'people': 189,
#  'homeless': 190,
#  'lost': 191,
#  'cause': 192,
#  'while': 193,
#  'worrying': 194,
#  'things': 195,
#  'racism': 196,
#  'war': 197,
#  'iraq': 198,
#  'pressuring': 199,
#  'kids': 200,
#  'succeed': 201,
#  'technology': 202,
#  'elections': 203,
#  'inflation': 204,
#  'if': 205,
#  'they': 206,
#  'll': 207,
#  'next': 208,
#  'end': 209,
#  'up': 210,
#  'streets': 211,
#  'br': 212,
#  'given': 213,
#  'bet': 214,
#  'live': 215,
#  'month': 216,
#  'without': 217,
#  'luxuries': 218,
#  'had': 219,
#  'home': 220,
#  'entertainment': 221,
#  'sets': 222,
#  'bathroom': 223,
#  'pictures': 224,
#  'wall': 225,
#  'computer': 226,
#  'treasure': 227,
#  'like': 228,
#  'goddard': 229,
#  'bolt': 230,
#  'lesson': 231,
#  'mel': 232,
#  'brooks': 233,
#  'directs': 234,
#  'plays': 235,
#  'rich': 236,
#  'world': 237,
#  'until': 238,
#  'deciding': 239,
#  'sissy': 240,
#  'rival': 241,
#  'jeffery': 242,
#  'tambor': 243,
#  'he': 244,
#  'thirty': 245,
#  'days': 246,
#  'succeeds': 247,
#  'do': 248,
#  'wants': 249,
#  'project': 250,
#  'more': 251,
#  'buildings': 252,
#  'where': 253,
#  'thrown': 254,
#  'bracelet': 255,
#  'his': 256,
#  'leg': 257,
#  'monitor': 258,
#  'every': 259,
#  'move': 260,
#  'step': 261,
#  'sidewalk': 262,
#  'nickname': 263,
#  'pepto': 264,
#  'vagrant': 265,
#  'after': 266,
#  'written': 267,
#  'forehead': 268,
#  'meets': 269,
#  'characters': 270,
#  'including': 271,
#  'woman': 272,
#  'name': 273,
#  'molly': 274,
#  'lesley': 275,
#  'ann': 276,
#  'warren': 277,
#  'ex': 278,
#  'dancer': 279,
#  'got': 280,
#  'divorce': 281,
#  'before': 282,
#  'losing': 283,
#  'her': 284,
#  'pals': 285,
#  'sailor': 286,
#  'howard': 287,
#  'morris': 288,
#  'fumes': 289,
#  'teddy': 290,
#  'wilson': 291,
#  'are': 292,
#  'already': 293,
#  'used': 294,
#  're': 295,
#  'survivors': 296,
#  'not': 297,
#  'reaching': 298,
#  'mutual': 299,
#  'agreements': 300,
#  'being': 301,
#  'fight': 302,
#  'flight': 303,
#  'kill': 304,
#  'killed': 305,
#  'love': 306,
#  'connection': 307,
#  'between': 308,
#  'wasn': 309,
#  'necessary': 310,
#  'plot': 311,
#  'found': 312,
#  'stinks': 313,
#  'observant': 314,
#  'films': 315,
#  'prior': 316,
#  'shows': 317,
#  'tender': 318,
#  'side': 319,
#  'compared': 320,
#  'slapstick': 321,
#  'blazing': 322,
#  'saddles': 323,
#  'young': 324,
#  'frankenstein': 325,
#  'spaceballs': 326,
#  'show': 327,
#  'having': 328,
#  'something': 329,
#  'valuable': 330,
#  'day': 331,
#  'hand': 332,
#  'stupid': 333,
#  'don': 334,
#  'know': 335,
#  'money': 336,
#  'maybe': 337,
#  'give': 338,
#  'instead': 339,
#  'using': 340,
#  'monopoly': 341,
#  'this': 342,
#  'film': 343,
#  'will': 344,
#  'inspire': 345,
#  'others': 346,
#  'airport': 347,
#  'brand': 348,
#  'new': 349,
#  'luxury': 350,
#  'plane': 351,
#  'loaded': 352,
#  'paintings': 353,
#  'belonging': 354,
#  'businessman': 355,
#  'philip': 356,
#  'stevens': 357,
#  'james': 358,
#  'stewart': 359,
#  'flying': 360,
#  'them': 361,
#  'bunch': 362,
#  'vip': 363,
#  'estate': 364,
#  'preparation': 365,
#  'opened': 366,
#  'public': 367,
#  'museum': 368,
#  'also': 369,
#  'board': 370,
#  'daughter': 371,
#  'julie': 372,
#  'kathleen': 373,
#  'quinlan': 374,
#  'son': 375,
#  'jetliner': 376,
#  'takes': 377,
#  'planned': 378,
#  'mid': 379,
#  'air': 380,
#  'hi': 381,
#  'jacked': 382,
#  'co': 383,
#  'pilot': 384,
#  'chambers': 385,
#  'robert': 386,
#  'foxworth': 387,
#  'two': 388,
#  'accomplice': 389,
#  'banker': 390,
#  'monte': 391,
#  'markham': 392,
#  'michael': 393,
#  'pataki': 394,
#  'knock': 395,
#  'passengers': 396,
#  'crew': 397,
#  'sleeping': 398,
#  'gas': 399,
#  'steal': 400,
#  'cargo': 401,
#  'land': 402,
#  'disused': 403,
#  'strip': 404,
#  'isolated': 405,
#  'island': 406,
#  'descent': 407,
#  'almost': 408,
#  'hits': 409,
#  'oil': 410,
#  'rig': 411,
#  'ocean': 412,
#  'loses': 413,
#  'control': 414,
#  'sending': 415,
#  'crashing': 416,
#  'sea': 417,
#  'sinks': 418,
#  'bottom': 419,
#  'bang': 420,
#  'middle': 421,
#  'bermuda': 422,
#  'triangle': 423,
#  'short': 424,
#  'supply': 425,
#  'water': 426,
#  'leaking': 427,
#  'flown': 428,
#  'over': 429,
#  'miles': 430,
#  'course': 431,
#  'problems': 432,
#  'mount': 433,
#  'survivor': 434,
#  'await': 435,
#  'fast': 436,
#  'running': 437,
#  'known': 438,
#  'under': 439,
#  'slightly': 440,
#  'different': 441,
#  'tile': 442,
#  'second': 443,
#  'sequel': 444,
#  'smash': 445,
#  'hit': 446,
#  'disaster': 447,
#  'thriller': 448,
#  'was': 449,
#  'directed': 450,
#  'jerry': 451,
#  'jameson': 452,
#  'again': 453,
#  'predecessors': 454,
#  'say': 455,
#  'any': 456,
#  'sort': 457,
#  'forgotten': 458,
#  'entertaining': 459,
#  'although': 460,
#  'necessarily': 461,
#  'reasons': 462,
#  'three': 463,
#  'have': 464,
#  'so': 465,
#  'actually': 466,
#  'liked': 467,
#  'best': 468,
#  'favourite': 469,
#  'nice': 470,
#  'jacking': 471,
#  'then': 472,
#  'didn': 473,
#  'sinking': 474,
#  'makers': 475,
#  'trying': 476,
#  'cross': 477,
#  'original': 478,
#  'another': 479,
#  'popular': 480,
#  'flick': 481,
#  'period': 482,
#  'poseidon': 483,
#  'adventure': 484,
#  'submerged': 485,
#  'stark': 486,
#  'dilemma': 487,
#  'facing': 488,
#  'trapped': 489,
#  'inside': 490,
#  'either': 491,
#  'suffocate': 492,
#  'runs': 493,
#  'drown': 494,
#  'floods': 495,
#  'doors': 496,
#  'decent': 497,
#  'idea': 498,
#  'could': 499,
#  'made': 500,
#  'little': 501,
#  'bad': 502,
#  'unsympathetic': 503,
#  'character': 504,
#  'dull': 505,
#  'lethargic': 506,
#  'set': 507,
#  'pieces': 508,
#  'real': 509,
#  'lack': 510,
#  'danger': 511,
#  'suspense': 512,
#  'tension': 513,
#  'means': 514,
#  'missed': 515,
#  'opportunity': 516,
#  'rather': 517,
#  'sluggish': 518,
#  'keeps': 519,
#  'entertained': 520,
#  'odd': 521,
#  'minutes': 522,
#  'happens': 523,
#  'there': 524,
#  'urgency': 525,
#  'thought': 526,
#  'navy': 527,
#  'become': 528,
#  'involved': 529,
#  'pick': 530,
#  'few': 531,
#  'shots': 532,
#  'huge': 533,
#  'ships': 534,
#  'helicopters': 535,
#  'lacking': 536,
#  'kennedy': 537,
#  'jinxed': 538,
#  'airline': 539,
#  'worker': 540,
#  'joe': 541,
#  'patroni': 542,
#  'back': 543,
#  'only': 544,
#  'gets': 545,
#  'couple': 546,
#  'scenes': 547,
#  'barely': 548,
#  'says': 549,
#  'anything': 550,
#  'preferring': 551,
#  'look': 552,
#  'worried': 553,
#  'background': 554,
#  'video': 555,
#  'theatrical': 556,
#  'version': 557,
#  'run': 558,
#  'us': 559,
#  'tv': 560,
#  'versions': 561,
#  'add': 562,
#  'extra': 563,
#  'hour': 564,
#  'footage': 565,
#  'credits': 566,
#  'sequence': 567,
#  'flashbacks': 568,
#  'flesh': 569,
#  'longer': 570,
#  'rescue': 571,
#  'discovery': 572,
#  'dead': 573,
#  'bodies': 574,
#  'navigator': 575,
#  'am': 576,
#  'sure': 577,
#  'sit': 578,
#  'near': 579,
#  'cut': 580,
#  'expected': 581,
#  'dated': 582,
#  'badly': 583,
#  'horrible': 584,
#  'fashions': 585,
#  'interior': 586,
#  'design': 587,
#  'choices': 588,
#  'toy': 589,
#  'model': 590,
#  'effects': 591,
#  'aren': 592,
#  'along': 593,
#  'sequels': 594,
#  'pride': 595,
#  'place': 596,
#  'razzie': 597,
#  'award': 598,
#  'hall': 599,
#  'shame': 600,
#  'lots': 601,
#  'worse': 602,
#  'reckon': 603,
#  'harsh': 604,
#  'action': 605,
#  'pace': 606,
#  'slow': 607,
#  'excitement': 608,
#  'generated': 609,
#  'pretty': 610,
#  'properly': 611,
#  'production': 612,
#  'values': 613,
#  'alright': 614,
#  'nothing': 615,
#  'spectacular': 616,
#  'acting': 617,
#  'oscar': 618,
#  'winner': 619,
#  'jack': 620,
#  'lemmon': 621,
#  'said': 622,
#  'since': 623,
#  'mistake': 624,
#  'star': 625,
#  'looks': 626,
#  'old': 627,
#  'frail': 628,
#  'lee': 629,
#  'grant': 630,
#  'drunk': 631,
#  'sir': 632,
#  'christopher': 633,
#  'plenty': 634,
#  'familiar': 635,
#  'faces': 636,
#  'orientated': 637,
#  'ideas': 638,
#  'behind': 639,
#  'bit': 640,
#  'silly': 641,
#  'bland': 642,
#  'direction': 643,
#  'doesn': 644,
#  'though': 645,
#  'sunken': 646,
#  'shouldn': 647,
#  'boring': 648,
#  'followed': 649,
#  'concorde': 650,
#  'brilliant': 651,
#  'dramatic': 652,
#  'hobo': 653,
#  'lady': 654,
#  'ever': 655,
#  'clothes': 656,
#  'warehouse': 657,
#  'none': 658,
#  'corn': 659,
#  'face': 660,
#  'take': 661,
#  'lawyers': 662,
#  'superb': 663,
#  'accused': 664,
#  'turncoat': 665,
#  'selling': 666,
#  'boss': 667,
#  'dishonest': 668,
#  'lawyer': 669,
#  'shrugs': 670,
#  'indifferently': 671,
#  'funny': 672,
#  'words': 673,
#  'jeffrey': 674,
#  'favorite': 675,
#  'later': 676,
#  'larry': 677,
#  'sanders': 678,
#  'fantastic': 679,
#  'mad': 680,
#  'millionaire': 681,
#  'crush': 682,
#  'ghetto': 683,
#  'malevolent': 684,
#  'usual': 685,
#  'hospital': 686,
#  'invade': 687,
#  'demolition': 688,
#  'site': 689,
#  'classics': 690,
#  'legs': 691,
#  'big': 692,
#  'diggers': 693,
#  'fighting': 694,
#  'bleeds': 695,
#  'movie': 696,
#  'each': 697,
#  'quite': 698,
#  'often': 699,
#  'lacked': 700,
#  'couldn': 701,
#  'put': 702,
#  'finger': 703,
#  'first': 704,
#  'charisma': 705,
#  'part': 706,
#  'leading': 707,
#  'actress': 708,
#  'inevitably': 709,
#  'translated': 710,
#  'chemistry': 711,
#  'she': 712,
#  'shared': 713,
#  'screen': 714,
#  'romantic': 715,
#  'came': 716,
#  'across': 717,
#  'merely': 718,
#  'actors': 719,
#  'play': 720,
#  'very': 721,
#  'well': 722,
#  'director': 723,
#  'miscalculated': 724,
#  'needed': 725,
#  'screenplay': 726,
#  'exactly': 727,
#  'chef': 728,
#  'seemed': 729,
#  'enamored': 730,
#  'culinary': 731,
#  'skills': 732,
#  'restaurant': 733,
#  'ultimately': 734,
#  'himself': 735,
#  'youthful': 736,
#  'exploits': 737,
#  'anybody': 738,
#  'else': 739,
#  'convinced': 740,
#  'princess': 741,
#  'disappointed': 742,
#  'forget': 743,
#  'nominated': 744,
#  'judge': 745,
#  'yourself': 746,
#  'easily': 747,
#  'underrated': 748,
#  'inn': 749,
#  'cannon': 750,
#  'its': 751,
#  'flawed': 752,
#  'does': 753,
#  'realistic': 754,
#  'view': 755,
#  'unlike': 756,
#  'how': 757,
#  'citizen': 758,
#  'kane': 759,
#  'gave': 760,
#  'lounge': 761,
#  'titanic': 762,
#  'italians': 763,
#  'idiots': 764,
#  'jokes': 765,
#  'fall': 766,
#  'flat': 767,
#  'still': 768,
#  'lovable': 769,
#  'way': 770,
#  'comedies': 771,
#  'pull': 772,
#  'traditionally': 773,
#  'reviled': 774,
#  'members': 775,
#  'society': 776,
#  'truly': 777,
#  'impressive': 778,
#  'fisher': 779,
#  'king': 780,
#  'crap': 781,
#  'complaint': 782,
#  'cast': 783,
#  'someone': 784,
#  'writer': 785,
#  'sorry': 786,
#  'everyone': 787,
#  'supposed': 788,
#  'art': 789,
#  'wow': 790,
#  'handed': 791,
#  'guns': 792,
#  'screening': 793,
#  'blow': 794,
#  'brains': 795,
#  'watch': 796,
#  'photographic': 797,
#  'excellent': 798,
#  'painful': 799,
#  'absence': 800,
#  'sound': 801,
#  'track': 802,
#  'brutal': 803,
#  'loooonnnnng': 804,
#  'long': 805,
#  'sitting': 806,
#  'talking': 807,
#  'especially': 808,
#  'complaining': 809,
#  'really': 810,
#  'hard': 811,
#  'getting': 812,
#  'performances': 813,
#  'dark': 814,
#  'sombre': 815,
#  'uninspired': 816,
#  'stuff': 817,
#  'thing': 818,
#  'maureen': 819,
#  'stapleton': 820,
#  'red': 821,
#  'dress': 822,
#  'dancing': 823,
#  'otherwise': 824,
#  'ripoff': 825,
#  'bergman': 826,
#  'fan': 827,
#  'f': 828,
#  'anyone': 829,
#  'enjoyed': 830,
#  'hours': 831,
#  'lying': 832,
#  'typical': 833,
#  'less': 834,
#  'movies': 835,
#  'followable': 836,
#  'leslie': 837,
#  'rated': 838,
#  'moments': 839,
#  'fleshed': 840,
#  'probably': 841,
#  'room': 842,
#  'worth': 843,
#  'price': 844,
#  'rent': 845,
#  'overall': 846,
#  'job': 847,
#  'characteristic': 848,
#  'speaking': 849,
#  'directly': 850,
#  'actor': 851,
#  'fume': 852,
#  'both': 853,
#  'played': 854,
#  'parts': 855,
#  'parents': 856,
#  'took': 857,
#  'theater': 858,
#  'interiors': 859,
#  'watched': 860,
#  'we': 861,
#  'walked': 862,
#  'recently': 863,
#  'lived': 864,
#  'rest': 865,
#  'pretentious': 866,
#  'ponderous': 867,
#  'painfully': 868,
#  'piece': 869,
#  'wine': 870,
#  'cheese': 871,
#  'tripe': 872,
#  'woody': 873,
#  'allen': 874,
#  'directors': 875,
#  'worst': 876,
#  'career': 877,
#  'unmistakable': 878,
#  'style': 879,
#  'ingmar': 880,
#  'berman': 881,
#  'gives': 882,
#  'angular': 883,
#  'muted': 884,
#  'insight': 885,
#  'lives': 886,
#  'family': 887,
#  'wrought': 888,
#  'psychological': 889,
#  'damage': 890,
#  'caused': 891,
#  'estrangement': 892,
#  'non': 893,
#  'halitosis': 894,
#  'whatever': 895,
#  'intentionally': 896,
#  'comic': 897,
#  'relief': 898,
#  'music': 899,
#  'drenched': 900,
#  'shadowy': 901,
#  'pathos': 902,
#  'defined': 903,
#  'expressionist': 904,
#  'nature': 905,
#  'improvisational': 906,
#  'method': 907,
#  'illicit': 908,
#  'pronounced': 909,
#  'depth': 910,
#  'meaning': 911,
#  'truth': 912,
#  'beyond': 913,
#  'simply': 914,
#  'sympathy': 915,
#  'felt': 916,
#  'contempt': 917,
#  'parade': 918,
#  'shuffling': 919,
#  'whining': 920,
#  'nicotine': 921,
#  'stained': 922,
#  'martyrs': 923,
#  'perpetual': 924,
#  'quest': 925,
#  'identity': 926,
#  'amid': 927,
#  'backdrop': 928,
#  'cosmopolitan': 929,
#  'affluence': 930,
#  'baked': 931,
#  'brie': 932,
#  'intelligentsia': 933,
#  'looms': 934,
#  'fart': 935,
#  'speaks': 936,
#  'affected': 937,
#  'platitudes': 938,
#  'elevated': 939,
#  'language': 940,
#  'cigarettes': 941,
#  'struggling': 942,
#  'desperate': 943,
#  'find': 944,
#  'understanding': 945,
#  'goes': 946,
#  'point': 947,
#  'want': 948,
#  'slap': 949,
#  'resolution': 950,
#  'interminable': 951,
#  'introspective': 952,
#  'babble': 953,
#  'drama': 954,
#  'taken': 955,
#  'extreme': 956,
#  'ability': 957,
#  'connect': 958,
#  'chose': 959,
#  'immersed': 960,
#  'themselves': 961,
#  'feel': 962,
#  'left': 963,
#  'reason': 964,
#  'self': 965,
#  'indulgent': 966,
#  'spiritually': 967,
#  'draining': 968,
#  'insistence': 969,
#  'promoting': 970,
#  'message': 971,
#  'prozac': 972,
#  'prose': 973,
#  'distorted': 974,
#  'techniques': 975,
#  'jettisons': 976,
#  'past': 977,
#  'relevance': 978,
#  'highly': 979,
#  'recommend': 980,
#  'feeling': 981,
#  'happy': 982,
#  'need': 983,
#  'death': 984,
#  'let': 985,
#  'pretend': 986,
#  'happened': 987,
#  'comedic': 988,
#  'robin': 989,
#  'williams': 990,
#  'nor': 991,
#  'quirky': 992,
#  'recent': 993,
#  'fame': 994,
#  'hybrid': 995,
#  'dramatization': 996,
#  'mixed': 997,
#  'per': 998,
#  'se': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    
    for word in review.split(" "):
        layer_0[0, word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 4.,  5.,  4., ...,  0.,  0., 18.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    return int(label == "POSITIVE")

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        for label in labels:
            label_vocab.add(label)
        
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for index, word in enumerate(review_vocab):
            self.word2index[word] = index
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for index, label in enumerate(label_vocab):
            self.label2index[label] = index
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros(shape=(input_nodes, hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(size=(hidden_nodes, output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        pass
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        pass
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        pass
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid function 
        pass

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        pass

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
